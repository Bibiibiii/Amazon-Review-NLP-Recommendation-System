# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('amazon_reviews_sample').getOrCreate()

# %matplotlib inline
import pyspark.sql.functions as f
#change configuration settings on Spark 
conf = spark.sparkContext._conf.setAll([('spark.executor.memory', '32g'), ('spark.app.name', 'Spark Updated Conf'), ('spark.executor.cores', '4'), ('spark.cores.max', '4'), ('spark.driver.memory','32g')])
spark.conf.set("spark.sql.repl.eagerEval.enabled",True)

#print spark configuration settings
spark.sparkContext.getConf().getAll()
# Out:
# [('spark.eventLog.enabled', 'true'),
#  ('spark.yarn.jars',
#   'local:/opt/cloudera/parcels/CDH-6.3.0-1.cdh6.3.0.p0.1279813/lib/spark/jars/*,local:/opt/cloudera/parcels/CDH-6.3.0-1.cdh6.3.0.p0.1279813/lib/spark/hive/*'),
#  ('spark.yarn.appMasterEnv.MKL_NUM_THREADS', '1'),
#  ('spark.sql.queryExecutionListeners',
#   'com.cloudera.spark.lineage.NavigatorQueryListener'),
#  ('spark.lineage.log.dir', '/var/log/spark/lineage'),
#  ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_HOSTS',
#   'md01.rcc.local,md02.rcc.local'),
#  ('spark.driver.port', '40763'),
#  ('spark.serializer', 'org.apache.spark.serializer.KryoSerializer'),
#  ('spark.executorEnv.PYTHONPATH',
#   '/opt/cloudera/parcels/CDH/lib/spark/python/lib/py4j-0.10.7-src.zip:/opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip<CPS>/opt/cloudera/parcels/CDH-6.3.0-1.cdh6.3.0.p0.1279813/lib/spark/python/lib/py4j-0.10.7-src.zip<CPS>/opt/cloudera/parcels/CDH-6.3.0-1.cdh6.3.0.p0.1279813/lib/spark/python/lib/pyspark.zip'),
#  ('spark.yarn.historyServer.address', 'http://hd01.rcc.local:18088'),
#  ('spark.ui.filters',
#   'org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter'),
#  ('spark.network.crypto.enabled', 'false'),
#  ('spark.executorEnv.MKL_NUM_THREADS', '1'),
#  ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.PROXY_URI_BASES',
#   'http://md01.rcc.local:8088/proxy/application_1634749823627_11524,http://md02.rcc.local:8088/proxy/application_1634749823627_11524'),
#  ('spark.ui.enabled', 'true'),
#  ('spark.executor.id', 'driver'),
#  ('spark.executor.extraLibraryPath',
#   '/opt/cloudera/parcels/CDH-6.3.0-1.cdh6.3.0.p0.1279813/lib/hadoop/lib/native'),
#  ('spark.dynamicAllocation.schedulerBacklogTimeout', '1'),
#  ('spark.yarn.config.gatewayPath', '/opt/cloudera/parcels'),
#  ('spark.extraListeners', 'com.cloudera.spark.lineage.NavigatorAppListener'),
#  ('spark.executor.memory', '32g'),
#  ('spark.port.maxRetries', '60'),
#  ('spark.driver.appUIAddress', 'http://md01.rcc.local:4050'),
#  ('spark.sql.warehouse.dir', '/user/hive/warehouse'),
#  ('spark.app.name', 'Spark Updated Conf'),
#  ('spark.sql.catalogImplementation', 'hive'),
#  ('spark.driver.log.persistToDfs.enabled', 'true'),
#  ('spark.yarn.config.replacementPath', '{{HADOOP_COMMON_HOME}}/../../..'),
#  ('spark.executorEnv.OPENBLAS_NUM_THREADS', '1'),
#  ('spark.ui.proxyBase', '/proxy/application_1634749823627_11524'),
#  ('spark.driver.extraLibraryPath',
#   '/opt/cloudera/parcels/CDH-6.3.0-1.cdh6.3.0.p0.1279813/lib/hadoop/lib/native'),
#  ('spark.driver.memory', '32g'),
#  ('spark.ui.killEnabled', 'true'),
#  ('spark.cores.max', '4'),
#  ('spark.eventLog.dir', 'hdfs://nameservice1/user/spark/applicationHistory'),
#  ('spark.dynamicAllocation.executorIdleTimeout', '60'),
#  ('spark.executor.cores', '4'),
#  ('spark.io.encryption.enabled', 'false'),
#  ('spark.authenticate', 'false'),
#  ('spark.app.id', 'application_1634749823627_11524'),
#  ('spark.serializer.objectStreamReset', '100'),
#  ('spark.submit.deployMode', 'client'),
#  ('spark.org.apache.hadoop.yarn.server.webproxy.amfilter.AmIpFilter.param.RM_HA_URLS',
#   'md01.rcc.local:8088,md02.rcc.local:8088'),
#  ('spark.shuffle.service.enabled', 'true'),
#  ('spark.yarn.historyServer.allowTracking', 'true'),
#  ('spark.yarn.appMasterEnv.OPENBLAS_NUM_THREADS', '1'),
#  ('spark.shuffle.service.port', '7337'),
#  ('spark.lineage.enabled', 'true'),
#  ('spark.master', 'yarn'),
#  ('spark.driver.host', 'md01.rcc.local'),
#  ('spark.rdd.compress', 'True'),
#  ('spark.yarn.am.extraLibraryPath',
#   '/opt/cloudera/parcels/CDH-6.3.0-1.cdh6.3.0.p0.1279813/lib/hadoop/lib/native'),
#  ('spark.dynamicAllocation.minExecutors', '0'),
#  ('spark.yarn.isPython', 'true'),
#  ('spark.dynamicAllocation.enabled', 'true'),
#  ('spark.ui.showConsoleProgress', 'true'),
#  ('spark.driver.log.dfsDir', '/user/spark/driverLogs')]

# %%
books = spark.read.json("/user/jianminb/data/books_5.json.gz")
books.printSchema()
# Out:
# root
#  |-- asin: string (nullable = true)
#  |-- helpful: array (nullable = true)
#  |    |-- element: long (containsNull = true)
#  |-- overall: double (nullable = true)
#  |-- reviewText: string (nullable = true)
#  |-- reviewTime: string (nullable = true)
#  |-- reviewerID: string (nullable = true)
#  |-- reviewerName: string (nullable = true)
#  |-- summary: string (nullable = true)
#  |-- unixReviewTime: long (nullable = true)

# %%
books = books.select("asin","overall","reviewerID")

# %%
books.dtypes
# Out:
# [('asin', 'string'),
#  ('helpful', 'array<bigint>'),
#  ('overall', 'double'),
#  ('reviewText', 'string'),
#  ('reviewTime', 'string'),
#  ('reviewerID', 'string'),
#  ('reviewerName', 'string'),
#  ('summary', 'string'),
#  ('unixReviewTime', 'bigint')]

# %%
from pyspark.sql.types import DoubleType
from pyspark.ml.recommendation import ALS
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.feature import OneHotEncoder, StringIndexer

# %%
stringIndexer = StringIndexer(inputCol="asin", outputCol="asinIndex")
model = stringIndexer.fit(books)
books_index = model.transform(books)

# %%
books_index.dtypes
# Out:
# [('asin', 'string'),
#  ('helpful', 'array<bigint>'),
#  ('overall', 'double'),
#  ('reviewText', 'string'),
#  ('reviewTime', 'string'),
#  ('reviewerID', 'string'),
#  ('reviewerName', 'string'),
#  ('summary', 'string'),
#  ('unixReviewTime', 'bigint'),
#  ('asinIndex', 'double')]

# %%
stringIndexer = StringIndexer(inputCol="reviewerID", outputCol="reviewerIDIndex")
model = stringIndexer.fit(books_index)
books1_index = model.transform(books_index)

# %%
books1_index.dtypes
# Out:
# [('asin', 'string'),
#  ('helpful', 'array<bigint>'),
#  ('overall', 'double'),
#  ('reviewText', 'string'),
#  ('reviewTime', 'string'),
#  ('reviewerID', 'string'),
#  ('reviewerName', 'string'),
#  ('summary', 'string'),
#  ('unixReviewTime', 'bigint'),
#  ('asinIndex', 'double'),
#  ('reviewerIDIndex', 'double')]

# %%
books2_index = books1_index.drop("reviewerID")
books2_index = books2_index.drop("asin")

# %%
books2_index.printSchema()
# Out:
# root
#  |-- overall: double (nullable = true)
#  |-- asinIndex: double (nullable = false)
#  |-- reviewerIDIndex: double (nullable = false)

# %%
training, test = books1_index.randomSplit([0.8,0.2])

# %%
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.ml.tuning import ParamGridBuilder, CrossValidator

# %%
# Build the recommendation model using ALS on the training data
# Note we set cold start strategy to 'drop' to ensure we don't get NaN evaluation metrics
als = ALS(maxIter=10, regParam=0.01, userCol="reviewerIDIndex", itemCol="asinIndex", ratingCol="overall",
          coldStartStrategy="drop", nonnegative = True)

# %%
# Add hyperparameters and their respective values to param_grid
param_grid = ParamGridBuilder() \
            .addGrid(als.rank, [10, 50]) \
            .addGrid(als.regParam, [.01, .05]) \
            .build()

# %%
# Add hyperparameters and their respective values to param_grid
param_grid2 = ParamGridBuilder() \
            .addGrid(als.rank, [50,100]) \
            .addGrid(als.regParam, [.05, 0.1]) \
            .build()

# %%
# Define evaluator as RMSE and print length of evaluator
evaluator = RegressionEvaluator(
           metricName="rmse", 
           labelCol="overall", 
           predictionCol="prediction") 
print ("Num models to be tested: ", len(param_grid))
# Out:
# Num models to be tested:  4

# %%
# Build cross validation using CrossValidator
cv = CrossValidator(estimator=als, estimatorParamMaps=param_grid, evaluator=evaluator, numFolds=3)

# %%
model_cv = cv.fit(training)

# %%
best_model = model_cv.bestModel

# %%
# Print best_model
print(type(best_model))

# Complete the code below to extract the ALS model parameters
print("**Best Model**")

# # Print "Rank"
print("  Rank:", best_model._java_obj.parent().getRank())

# Print "MaxIter"
print("  MaxIter:", best_model._java_obj.parent().getMaxIter())

# Print "RegParam"
print("  RegParam:", best_model._java_obj.parent().getRegParam())
# Out:
# <class 'pyspark.ml.recommendation.ALSModel'>
# **Best Model**
#   Rank: 50
#   MaxIter: 10
#   RegParam: 0.05

# %%
# View the predictions
test_predictions = best_model.transform(test)
RMSE = evaluator.evaluate(test_predictions)
print(RMSE)
# Out:
# 1.0357154239881492

# %%
# Build cross validation using CrossValidator
cv2 = CrossValidator(estimator=als, estimatorParamMaps=param_grid2, evaluator=evaluator, numFolds=3)

# %%
model_cv2 = cv2.fit(training)

# %%
best_model2 = model_cv2.bestModel

# %%
# Print best_model
print(type(best_model2))

# Complete the code below to extract the ALS model parameters
print("**Best Model**")

# # Print "Rank"
print("  Rank:", best_model2._java_obj.parent().getRank())

# Print "MaxIter"
print("  MaxIter:", best_model2._java_obj.parent().getMaxIter())

# Print "RegParam"
print("  RegParam:", best_model2._java_obj.parent().getRegParam())
# Out:
# <class 'pyspark.ml.recommendation.ALSModel'>
# **Best Model**
#   Rank: 100
#   MaxIter: 10
#   RegParam: 0.1

# %%
# View the predictions
test_predictions2 = best_model2.transform(test)
RMSE2 = evaluator.evaluate(test_predictions2)
print(RMSE2)
# Out:
# 0.9877977806109016

# %%
# Add hyperparameters and their respective values to param_grid
param_grid3 = ParamGridBuilder() \
            .addGrid(als.rank, [50,100,150]) \
            .addGrid(als.regParam, [0.01,0.05,0.1,0.15]) \
            .build()

# %%
# Build cross validation using CrossValidator
cv3 = CrossValidator(estimator=als, estimatorParamMaps=param_grid3, evaluator=evaluator, numFolds=3)

# %%
model_cv3 = cv3.fit(training)

# %%
best_model3 = model_cv3.bestModel

# %%
# Print best_model
print(type(best_model3))

# Complete the code below to extract the ALS model parameters
print("**Best Model**")

# # Print "Rank"
print("  Rank:", best_model3._java_obj.parent().getRank())

# Print "MaxIter"
print("  MaxIter:", best_model3._java_obj.parent().getMaxIter())

# Print "RegParam"
print("  RegParam:", best_model3._java_obj.parent().getRegParam())
# Out:
# <class 'pyspark.ml.recommendation.ALSModel'>
# **Best Model**
#   Rank: 150
#   MaxIter: 10
#   RegParam: 0.15

# %%
# View the predictions
test_predictions3 = best_model3.transform(test)
RMSE3 = evaluator.evaluate(test_predictions3)
print(RMSE3)
# Out:
# 0.9824782504983577

# %%
# Add hyperparameters and their respective values to param_grid
param_grid4 = ParamGridBuilder() \
            .addGrid(als.rank, [150,200]) \
            .addGrid(als.regParam, [0.15,0.2,0.25]) \
            .build()

# %%
# Build cross validation using CrossValidator
cv4 = CrossValidator(estimator=als, estimatorParamMaps=param_grid4, evaluator=evaluator, numFolds=3)

# %%
model_cv4 = cv4.fit(training)
# Out:
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-84-ba84cf1dbec7> in <module>()
# ----> 1 model_cv4 = cv4.fit(training)
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip/pyspark/ml/base.py in fit(self, dataset, params)
#     130                 return self.copy(params)._fit(dataset)
#     131             else:
# --> 132                 return self._fit(dataset)
#     133         else:
#     134             raise ValueError("Params must be either a param map or a list/tuple of param maps, "
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip/pyspark/ml/tuning.py in _fit(self, dataset)
#     302
#     303             tasks = _parallelFitTasks(est, train, eva, validation, epm, collectSubModelsParam)
# --> 304             for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#     305                 metrics[j] += (metric / nFolds)
#     306                 if collectSubModelsParam:
#
# /software/Anaconda3-5.1.0-hadoop/lib/python3.6/multiprocessing/pool.py in next(self, timeout)
#     733         if success:
#     734             return value
# --> 735         raise value
#     736
#     737     __next__ = next                    # XXX
#
# /software/Anaconda3-5.1.0-hadoop/lib/python3.6/multiprocessing/pool.py in worker(inqueue, outqueue, initializer, initargs, maxtasks, wrap_exception)
#     117         job, i, func, args, kwds = task
#     118         try:
# --> 119             result = (True, func(*args, **kwds))
#     120         except Exception as e:
#     121             if wrap_exception and func is not _helper_reraises_exception:
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip/pyspark/ml/tuning.py in <lambda>(f)
#     302
#     303             tasks = _parallelFitTasks(est, train, eva, validation, epm, collectSubModelsParam)
# --> 304             for j, metric, subModel in pool.imap_unordered(lambda f: f(), tasks):
#     305                 metrics[j] += (metric / nFolds)
#     306                 if collectSubModelsParam:
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip/pyspark/ml/tuning.py in singleTask()
#      51     def singleTask():
#      52         index, model = next(modelIter)
# ---> 53         metric = eva.evaluate(model.transform(validation, epm[index]))
#      54         return index, metric, model if collectSubModel else None
#      55
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip/pyspark/ml/evaluation.py in evaluate(self, dataset, params)
#      69                 return self.copy(params)._evaluate(dataset)
#      70             else:
# ---> 71                 return self._evaluate(dataset)
#      72         else:
#      73             raise ValueError("Params must be a param map but got %s." % type(params))
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip/pyspark/ml/evaluation.py in _evaluate(self, dataset)
#      99         """
#     100         self._transfer_params_to_java()
# --> 101         return self._java_obj.evaluate(dataset._jdf)
#     102
#     103     def isLargerBetter(self):
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/py4j-0.10.7-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1255         answer = self.gateway_client.send_command(command)
#    1256         return_value = get_return_value(
# -> 1257             answer, self.gateway_client, self.target_id, self.name)
#    1258
#    1259         for temp_arg in temp_args:
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/pyspark.zip/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /opt/cloudera/parcels/CDH/lib/spark/python/lib/py4j-0.10.7-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     326                 raise Py4JJavaError(
#     327                     "An error occurred while calling {0}{1}{2}.\n".
# --> 328                     format(target_id, ".", name), value)
#     329             else:
#     330                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o758.evaluate.
# : org.apache.spark.SparkException: Job aborted due to stage failure: Task 0 in stage 4787.0 failed 4 times, most recent failure: Lost task 0.3 in stage 4787.0 (TID 43511, hd04.rcc.local, executor 561): ExecutorLostFailure (executor 561 exited caused by one of the running tasks) Reason: Container killed by YARN for exceeding memory limits.  1.5 GB of 1.5 GB physical memory used. Consider boosting spark.yarn.executor.memoryOverhead or disabling yarn.nodemanager.vmem-check-enabled because of YARN-4714.
# Driver stacktrace:
# 	at org.apache.spark.scheduler.DAGScheduler.org$apache$spark$scheduler$DAGScheduler$$failJobAndIndependentStages(DAGScheduler.scala:1890)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1878)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$abortStage$1.apply(DAGScheduler.scala:1877)
# 	at scala.collection.mutable.ResizableArray$class.foreach(ResizableArray.scala:59)
# 	at scala.collection.mutable.ArrayBuffer.foreach(ArrayBuffer.scala:48)
# 	at org.apache.spark.scheduler.DAGScheduler.abortStage(DAGScheduler.scala:1877)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:929)
# 	at org.apache.spark.scheduler.DAGScheduler$$anonfun$handleTaskSetFailed$1.apply(DAGScheduler.scala:929)
# 	at scala.Option.foreach(Option.scala:257)
# 	at org.apache.spark.scheduler.DAGScheduler.handleTaskSetFailed(DAGScheduler.scala:929)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.doOnReceive(DAGScheduler.scala:2111)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2060)
# 	at org.apache.spark.scheduler.DAGSchedulerEventProcessLoop.onReceive(DAGScheduler.scala:2049)
# 	at org.apache.spark.util.EventLoop$$anon$1.run(EventLoop.scala:49)
# 	at org.apache.spark.scheduler.DAGScheduler.runJob(DAGScheduler.scala:740)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2081)
# 	at org.apache.spark.SparkContext.runJob(SparkContext.scala:2178)
# 	at org.apache.spark.rdd.RDD$$anonfun$fold$1.apply(RDD.scala:1098)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.RDD.fold(RDD.scala:1092)
# 	at org.apache.spark.rdd.RDD$$anonfun$treeAggregate$1.apply(RDD.scala:1161)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.RDD.treeAggregate(RDD.scala:1137)
# 	at org.apache.spark.mllib.evaluation.RegressionMetrics.summary$lzycompute(RegressionMetrics.scala:57)
# 	at org.apache.spark.mllib.evaluation.RegressionMetrics.summary(RegressionMetrics.scala:54)
# 	at org.apache.spark.mllib.evaluation.RegressionMetrics.SSerr$lzycompute(RegressionMetrics.scala:65)
# 	at org.apache.spark.mllib.evaluation.RegressionMetrics.SSerr(RegressionMetrics.scala:65)
# 	at org.apache.spark.mllib.evaluation.RegressionMetrics.meanSquaredError(RegressionMetrics.scala:100)
# 	at org.apache.spark.mllib.evaluation.RegressionMetrics.rootMeanSquaredError(RegressionMetrics.scala:109)
# 	at org.apache.spark.ml.evaluation.RegressionEvaluator.evaluate(RegressionEvaluator.scala:86)
# 	at sun.reflect.GeneratedMethodAccessor233.invoke(Unknown Source)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:238)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
best_model4 = model_cv4.bestModel

# %%
# Print best_model
print(type(best_model4))

# Complete the code below to extract the ALS model parameters
print("**Best Model**")

# # Print "Rank"
print("  Rank:", best_model4._java_obj.parent().getRank())

# Print "MaxIter"
print("  MaxIter:", best_model4._java_obj.parent().getMaxIter())

# Print "RegParam"
print("  RegParam:", best_model4._java_obj.parent().getRegParam())

# %%
# View the predictions
test_predictions4 = best_model4.transform(test)
RMSE4 = evaluator.evaluate(test_predictions4)
print(RMSE4)

# %%
#fit and predict
model = als.fit(training)
predictions = model.transform(test)

# %%
evaluator = RegressionEvaluator(metricName='rmse', labelCol='overall')
rmse = evaluator.evaluate(predictions)
print("Root-mean-square error = " + str(rmse))
# Out:
# Root-mean-square error = 1.3619927172186903

# %%
#explain parameters of the model
model.explainParams()
# Out:
# 'coldStartStrategy: strategy for dealing with unknown or new users/items at prediction time. This may be useful in cross-validation or production scenarios, for handling user/item ids the model has not seen in the training data. Supported values: nan,drop. (default: nan, current: drop)\nitemCol: column name for item ids. Ids must be within the integer value range. (default: item, current: asinIndex)\npredictionCol: prediction column name (default: prediction)\nuserCol: column name for user ids. Ids must be within the integer value range. (default: user, current: reviewerIDIndex)'

# %%
#item factors 
model.itemFactors.show(10, truncate = False)
# Out:
# +---+---------------------------------------------------------------------------------------------------------------------+
# |id |features                                                                                                             |
# +---+---------------------------------------------------------------------------------------------------------------------+
# |0  |[0.9989152, 0.6086671, 0.0, 1.1316842, 0.14719044, 0.4466637, 0.63492686, 0.708429, 0.8661433, 0.96513003]           |
# |10 |[1.0328232, 0.35163817, 0.39595658, 0.5199836, 0.8044754, 0.9919952, 0.60510373, 0.6314512, 0.37546015, 1.0589483]   |
# |20 |[0.9003094, 0.79917353, 0.69117737, 0.47700605, 0.70824647, 0.8046747, 0.8154053, 0.9168871, 0.56048584, 0.6843929]  |
# |30 |[0.97663516, 0.62136, 0.4612496, 0.4295348, 0.96013474, 0.83717257, 0.924034, 0.12046359, 0.8095437, 0.95464647]     |
# |40 |[0.75584763, 0.56663465, 0.7882819, 0.93283737, 0.7941211, 0.18517363, 0.33851552, 1.0515912, 0.7521167, 0.81481457] |
# |50 |[0.80335605, 0.96555656, 0.7567584, 0.6929407, 0.83383685, 0.84090906, 0.68736327, 0.7229216, 0.58070534, 0.95191467]|
# |60 |[1.2613771, 0.36591223, 0.6664169, 0.17849231, 0.4975309, 0.8216447, 0.47529975, 0.8008977, 0.38294935, 1.1342142]   |
# |70 |[0.7916289, 1.2279539, 0.77653295, 0.965831, 0.8104622, 0.8505826, 0.63995886, 0.6598051, 0.68005043, 0.7402971]     |
# |80 |[0.51821584, 0.0, 0.5380827, 0.64422214, 0.0, 0.94391304, 0.5578836, 0.79084885, 0.33845663, 1.2448986]              |
# |90 |[0.9590036, 0.52782077, 0.6464233, 0.5923835, 0.1527109, 0.9712486, 0.24566416, 0.9147363, 0.7325898, 1.0165069]     |
# +---+---------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
from pyspark.sql import functions as func
from pyspark.sql.functions import explode, col

# %%
# Generate top 10 book recommendations for each user
userRecs = model.recommendForAllUsers(10)
userRecs.show(10, truncate=False)
# Out:
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |reviewerIDIndex|recommendations                                                                                                                                                                                                   |
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |148            |[[326409, 10.956128], [267975, 10.946776], [311108, 10.835842], [344111, 10.823646], [207236, 10.767737], [153367, 10.761895], [274360, 10.692666], [287024, 10.681555], [257191, 10.679497], [152127, 10.637549]]|
# |463            |[[154298, 11.324488], [66406, 10.42019], [255212, 10.123577], [126281, 10.062067], [326409, 9.866618], [311108, 9.809768], [281744, 9.78767], [335568, 9.769164], [308334, 9.725137], [183679, 9.7166]]           |
# |471            |[[80150, 11.323336], [331096, 11.279375], [343863, 10.966273], [261562, 10.89492], [216677, 10.644038], [188082, 10.562451], [347860, 10.533466], [218112, 10.398656], [311108, 10.383862], [245530, 10.321095]]  |
# |496            |[[343863, 11.357021], [347860, 11.214703], [264383, 11.098201], [337176, 11.034457], [358483, 11.012765], [257191, 10.993747], [231988, 10.965314], [230667, 10.953621], [343003, 10.925496], [188082, 10.864666]]|
# |833            |[[344111, 10.0991335], [267975, 10.025108], [260682, 9.957423], [326409, 9.916433], [335568, 9.762835], [250442, 9.7273855], [257191, 9.711587], [311108, 9.694446], [231988, 9.670617], [314016, 9.617891]]      |
# |1088           |[[216677, 11.198038], [80150, 11.136375], [362007, 9.977527], [130243, 9.644294], [311108, 9.600542], [343863, 9.561043], [126281, 9.55134], [261562, 9.527794], [342539, 9.46346], [153367, 9.421931]]           |
# |1238           |[[255212, 13.26959], [261562, 13.1709585], [331096, 13.08329], [362007, 13.000875], [144083, 12.68514], [356551, 12.581722], [87433, 12.527565], [352125, 12.469933], [119199, 12.450475], [227642, 12.348816]]   |
# |1342           |[[309686, 10.298146], [274360, 10.25325], [227642, 10.22217], [311108, 10.208679], [267975, 10.105843], [260682, 10.057131], [188082, 10.053499], [343863, 10.045781], [366581, 9.989786], [344111, 9.957331]]    |
# |1580           |[[261562, 12.390806], [343863, 11.913299], [341608, 11.811904], [336564, 11.711376], [245530, 11.678401], [337176, 11.670877], [326409, 11.484107], [188082, 11.464007], [153367, 11.375059], [311108, 11.364378]]|
# |1591           |[[149395, 12.472471], [144083, 12.458244], [231593, 12.387583], [102555, 12.080776], [262683, 12.022446], [356551, 11.758145], [184861, 11.689608], [216256, 11.579885], [331096, 11.575472], [207236, 11.544527]]|
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
udf_item_index = udf(lambda x:x[0],FloatType())
udf_rating = udf(lambda x: x[1], FloatType())

# %%
from pyspark.sql.functions import udf

# %%
from pyspark.sql.types import StructType, FloatType, IntegerType

# %%
df_recommendation = userRecs.withColumn("recommendations",explode("recommendations"))

# %%
udf_item_index = udf(lambda x:x[0],IntegerType())
udf_rating = udf(lambda x: x[1], FloatType())

# %%
df_recommendation.withColumn('asinIndex', udf_item_index('recommendations')).withColumn('overall', udf_rating('recommendations'))
# Out:
# +---------------+-------------------+---------+---------+
# |reviewerIDIndex|    recommendations|asinIndex|  overall|
# +---------------+-------------------+---------+---------+
# |            148|[324579, 11.239884]|     null|11.239884|
# |            148|[294762, 10.652662]|     null|10.652662|
# |            148|[218873, 10.610807]|     null|10.610807|
# |            148|[134777, 10.592444]|     null|10.592444|
# |            148|[337798, 10.329012]|     null|10.329012|
# |            148|[253057, 10.318841]|     null|10.318841|
# |            148|[360592, 10.291299]|     null|10.291299|
# |            148|[316419, 10.264614]|     null|10.264614|
# |            148|[185895, 10.260252]|     null|10.260252|
# |            148|[128506, 10.239238]|     null|10.239238|
# |            463|[333898, 12.586649]|     null|12.586649|
# |            463|[185895, 11.061426]|     null|11.061426|
# |            463|[129382, 10.759244]|     null|10.759244|
# |            463| [92094, 10.623877]|     null|10.623877|
# |            463|[173985, 10.109651]|     null|10.109651|
# |            463|[267671, 10.008165]|     null|10.008165|
# |            463| [72942, 9.9977665]|     null|9.9977665|
# |            463| [330384, 9.992572]|     null| 9.992572|
# |            463| [140840, 9.948231]|     null| 9.948231|
# |            463|  [93338, 9.947626]|     null| 9.947626|
# +---------------+-------------------+---------+---------+
# only showing top 20 rows

# %%
nrecommendations = df_recommendation.withColumn('asinIndex', udf_item_index('recommendations')).withColumn('overall', udf_rating('recommendations')).drop('recommendations')
nrecommendations.limit(20).show()
# Out:
# +---------------+---------+----------+
# |reviewerIDIndex|asinIndex|   overall|
# +---------------+---------+----------+
# |            134|   343863| 11.708134|
# |            134|   274360| 11.634775|
# |            134|   245530| 11.588929|
# |            134|   188082| 11.539589|
# |            134|   153367| 11.535437|
# |            134|   227642| 11.518301|
# |            134|   227242| 11.516125|
# |            134|   188687| 11.504252|
# |            134|   240691| 11.491187|
# |            134|   257191| 11.477867|
# |            584|   351360| 10.753606|
# |            584|   292159| 10.599555|
# |            584|   362007| 10.584541|
# |            584|   188082| 10.328151|
# |            584|   260682|10.3169365|
# |            584|   257191| 10.299189|
# |            584|   197354| 10.245995|
# |            584|   188687| 10.210522|
# |            584|   341812| 10.187984|
# |            584|   281154| 10.186992|
# +---------------+---------+----------+

# %%
Meta_Books = spark.read.json("/user/jianminb/data/Meta_Books.json.gz")
Meta_Books.printSchema()
# Out:
# root
#  |-- also_buy: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- also_view: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- asin: string (nullable = true)
#  |-- brand: string (nullable = true)
#  |-- category: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- date: string (nullable = true)
#  |-- description: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- details: struct (nullable = true)
#  |    |--
#     Item Weight:
#     : string (nullable = true)
#  |    |--
#     Package Dimensions:
#     : string (nullable = true)
#  |    |--
#     Product Dimensions:
#     : string (nullable = true)
#  |    |--  Date first listed on Amazon:: string (nullable = true)
#  |    |-- 3.5" and 5.25" disks:: string (nullable = true)
#  |    |-- 3.5" disk:: string (nullable = true)
#  |    |-- 5.25" disk:: string (nullable = true)
#  |    |-- ASIN:: string (nullable = true)
#  |    |-- ASIN: : string (nullable = true)
#  |    |-- Accessory:: string (nullable = true)
#  |    |-- Age Range:: string (nullable = true)
#  |    |-- Album:: string (nullable = true)
#  |    |-- Audible.com Release Date:: string (nullable = true)
#  |    |-- Audio CD Library Binding:: string (nullable = true)
#  |    |-- Audio CD:: string (nullable = true)
#  |    |-- Audio Cassette:: string (nullable = true)
#  |    |-- Baby Product:: string (nullable = true)
#  |    |-- Bargain Book:: string (nullable = true)
#  |    |-- Bath Book:: string (nullable = true)
#  |    |-- Board book:: string (nullable = true)
#  |    |-- Bonded Leather:: string (nullable = true)
#  |    |-- Bookmark:: string (nullable = true)
#  |    |-- CD-ROM:: string (nullable = true)
#  |    |-- Calendar:: string (nullable = true)
#  |    |-- Card Book:: string (nullable = true)
#  |    |-- Cards:: string (nullable = true)
#  |    |-- Comic:: string (nullable = true)
#  |    |-- DCC (Digital Compact Cassette):: string (nullable = true)
#  |    |-- DVD Audio:: string (nullable = true)
#  |    |-- DVD-R:: string (nullable = true)
#  |    |-- DVD-ROM:: string (nullable = true)
#  |    |-- DVD:: string (nullable = true)
#  |    |-- Diary:: string (nullable = true)
#  |    |-- Diskette:: string (nullable = true)
#  |    |-- Domestic Shipping: : string (nullable = true)
#  |    |-- Electronics:: string (nullable = true)
#  |    |-- File Size:: string (nullable = true)
#  |    |-- Flexibound:: string (nullable = true)
#  |    |-- Foam Book:: string (nullable = true)
#  |    |-- Format:: string (nullable = true)
#  |    |-- Game:: string (nullable = true)
#  |    |-- Gift:: string (nullable = true)
#  |    |-- Grade Level:: string (nullable = true)
#  |    |-- Hardcover: string (nullable = true)
#  |    |-- Hardcover Comic:: string (nullable = true)
#  |    |-- Hardcover-spiral:: string (nullable = true)
#  |    |-- Hardcover:: string (nullable = true)
#  |    |-- Health and Beauty:: string (nullable = true)
#  |    |-- ISBN-10:: string (nullable = true)
#  |    |-- ISBN-13:: string (nullable = true)
#  |    |-- Imitation Leather:: string (nullable = true)
#  |    |-- International Shipping: : string (nullable = true)
#  |    |-- Item model number:: string (nullable = true)
#  |    |-- JP Oversized:: string (nullable = true)
#  |    |-- Journal:: string (nullable = true)
#  |    |-- Kindle Edition:: string (nullable = true)
#  |    |-- Kitchen:: string (nullable = true)
#  |    |-- Language:: string (nullable = true)
#  |    |-- Lawn & Patio:: string (nullable = true)
#  |    |-- Leather Bound:: string (nullable = true)
#  |    |-- Lending:: string (nullable = true)
#  |    |-- Lexile Measure:: string (nullable = true)
#  |    |-- Library Binding:: string (nullable = true)
#  |    |-- Listening Length:: string (nullable = true)
#  |    |-- Loose Leaf:: string (nullable = true)
#  |    |-- MP3 CD:: string (nullable = true)
#  |    |-- Map:: string (nullable = true)
#  |    |-- Mass Market Paperback:: string (nullable = true)
#  |    |-- Microfilm:: string (nullable = true)
#  |    |-- Misc. Supplies:: string (nullable = true)
#  |    |-- Misc.:: string (nullable = true)
#  |    |-- Mook:: string (nullable = true)
#  |    |-- Note:: string (nullable = true)
#  |    |-- Office Product:: string (nullable = true)
#  |    |-- Online Code:: string (nullable = true)
#  |    |-- Page Numbers Source ISBN:: string (nullable = true)
#  |    |-- Pamphlet:: string (nullable = true)
#  |    |-- Paperback: string (nullable = true)
#  |    |-- Paperback Bunko:: string (nullable = true)
#  |    |-- Paperback Shinsho:: string (nullable = true)
#  |    |-- Paperback:: string (nullable = true)
#  |    |-- Perfect Paperback:: string (nullable = true)
#  |    |-- Personal Computers:: string (nullable = true)
#  |    |-- Plastic Comb:: string (nullable = true)
#  |    |-- Pocket Book:: string (nullable = true)
#  |    |-- Poster:: string (nullable = true)
#  |    |-- Print Length:: string (nullable = true)
#  |    |-- Print Magazine:: string (nullable = true)
#  |    |-- Print on Demand (Paperback):: string (nullable = true)
#  |    |-- Printed Access Code:: string (nullable = true)
#  |    |-- Program Type:: string (nullable = true)
#  |    |-- Publication Date:: string (nullable = true)
#  |    |-- Publisher:: string (nullable = true)
#  |    |-- Rag Book:: string (nullable = true)
#  |    |-- Ring-bound:: string (nullable = true)
#  |    |-- School & Library Binding:: string (nullable = true)
#  |    |-- Series:: string (nullable = true)
#  |    |-- Sheet music:: string (nullable = true)
#  |    |-- Shipping Advisory:: string (nullable = true)
#  |    |-- Shipping Weight:: string (nullable = true)
#  |    |-- Shipping: : string (nullable = true)
#  |    |-- Simultaneous Device Usage:: string (nullable = true)
#  |    |-- Single Issue Magazine:: string (nullable = true)
#  |    |-- Slide:: string (nullable = true)
#  |    |-- Spiral-bound:: string (nullable = true)
#  |    |-- Staple Bound:: string (nullable = true)
#  |    |-- Stationery:: string (nullable = true)
#  |    |-- Tankobon Hardcover:: string (nullable = true)
#  |    |-- Tankobon Softcover:: string (nullable = true)
#  |    |-- Textbook Binding:: string (nullable = true)
#  |    |-- Toy:: string (nullable = true)
#  |    |-- Transparency:: string (nullable = true)
#  |    |-- Turtleback:: string (nullable = true)
#  |    |-- UPC:: string (nullable = true)
#  |    |-- Unbound:: string (nullable = true)
#  |    |-- Unknown Binding: string (nullable = true)
#  |    |-- Unknown Binding:: string (nullable = true)
#  |    |-- VHS Tape:: string (nullable = true)
#  |    |-- Version:: string (nullable = true)
#  |    |-- Video Game:: string (nullable = true)
#  |    |-- Vinyl Bound:: string (nullable = true)
#  |    |-- Wall Chart:: string (nullable = true)
#  |    |-- Whispersync for Voice:: string (nullable = true)
#  |    |-- Word Wise:: string (nullable = true)
#  |    |-- Workbook:: string (nullable = true)
#  |-- feature: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- fit: string (nullable = true)
#  |-- imageURL: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- imageURLHighRes: array (nullable = true)
#  |    |-- element: string (containsNull = true)
#  |-- main_cat: string (nullable = true)
#  |-- price: string (nullable = true)
#  |-- rank: string (nullable = true)
#  |-- similar_item: string (nullable = true)
#  |-- tech1: string (nullable = true)
#  |-- tech2: string (nullable = true)
#  |-- title: string (nullable = true)

# %%
Meta_Books_df = Meta_Books.select("asin","category",'price','title')

# %%
books_meta_index = books1_index.join(Meta_Books_df, on='asin')

# %%
books1_index.dtypes
# Out:
# [('asin', 'string'),
#  ('helpful', 'array<bigint>'),
#  ('overall', 'double'),
#  ('reviewText', 'string'),
#  ('reviewTime', 'string'),
#  ('reviewerID', 'string'),
#  ('reviewerName', 'string'),
#  ('summary', 'string'),
#  ('unixReviewTime', 'bigint'),
#  ('asinIndex', 'double'),
#  ('reviewerIDIndex', 'double')]

# %%
Meta_Books.select("asin","category",'price','title').show(10)
# Out:
# +----------+--------------------+-------+--------------------+
# |      asin|            category|  price|               title|
# +----------+--------------------+-------+--------------------+
# |0000092878|                  []| $39.94|Biology Gods Livi...|
# |000047715X|[Books, New, Used...|       |Mksap 16 Audio Co...|
# |0000004545|[Books, Arts & Ph...|$199.99|Flex! Discography...|
# |0000013765|[Books, Arts & Ph...|       |Heavenly Highway ...|
# |0000000116|                  []|$164.10|Georgina Goodman ...|
# |0000555010|[Books, New, Used...|       |Principles of Ana...|
# |0000477141|[Books, Medical B...|       |MKSAP 15 Audio Co...|
# |0000230022|[Books, New, Used...|       |The Simple Truths...|
# |0000038504|[Books, Education...|$198.70|Double-Speak: Fro...|
# |0000001589|                  []|       |LJ Classique Inte...|
# +----------+--------------------+-------+--------------------+
# only showing top 10 rows

# %%
books1_index.select('asin','asinIndex','reviewerID').show(10)
# Out:
# +----------+---------+--------------------+
# |      asin|asinIndex|          reviewerID|
# +----------+---------+--------------------+
# |000100039X|   4321.0|A10000012B7CGYKOM...|
# |000100039X|   4321.0|      A2S166WSCFIFP5|
# |000100039X|   4321.0|      A1BM81XB4QHOA3|
# |000100039X|   4321.0|      A1MOSTXNIO5MPJ|
# |000100039X|   4321.0|      A2XQ5LZHTD4AFT|
# |000100039X|   4321.0|      A3V1MKC2BVWY48|
# |000100039X|   4321.0|      A12387207U8U24|
# |000100039X|   4321.0|      A29TRDMK51GKZR|
# |000100039X|   4321.0|      A3FI0744PG1WYG|
# |000100039X|   4321.0|      A2LBBQHYLEHM7P|
# +----------+---------+--------------------+
# only showing top 10 rows

# %%
books1_index_recommend = books1_index.select('asin','overall','reviewerID','asinIndex')

# %%
books1_index.select('asin').distinct().show(10)
# Out:
# +----------+
# |      asin|
# +----------+
# |0002216973|
# |0006476155|
# |0006544150|
# |0006550479|
# |0007163932|
# |0023605103|
# |0027861317|
# |0028633784|
# |0060087447|
# |0060192097|
# +----------+
# only showing top 10 rows

# %%
books1_index_distinct = books1_index.select('asin','asinIndex').distinct()

# %%
books_meta_index_recommend = books1_index_distinct.join(Meta_Books_df, on='asin')

# %%
books_meta_index_recommend.select('asin').show(10)
# Out:
# +----------+
# |      asin|
# +----------+
# |0002216973|
# |0006476155|
# |0006544150|
# |0006550479|
# |0007163932|
# |0023605103|
# |0027861317|
# |0028633784|
# |0060192097|
# |0060392436|
# +----------+
# only showing top 10 rows

# %%
books1_index.select('overall').show(10)
# Out:
# +-------+
# |overall|
# +-------+
# |    5.0|
# |    5.0|
# |    5.0|
# |    5.0|
# |    5.0|
# |    5.0|
# |    5.0|
# |    5.0|
# |    5.0|
# |    5.0|
# +-------+
# only showing top 10 rows

# %%
books1_index.select('asin').count()
# Out:
# 8898041

# %%
Meta_Books.select('asin').count()
# Out:
# 2934949

# %% [markdown]
# # User A10000012B7CGYKOMPQ4L ALS Recommendations

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '3'").toPandas()
# Out:
#     asinIndex  reviewerIDIndex    overall        asin  overall  \
# 0      324579                3  11.828129  0979544114      5.0
# 1      324579                3  11.828129  0979544114      5.0
# 2      324579                3  11.828129  0979544114      5.0
# 3      324579                3  11.828129  0979544114      5.0
# 4      324579                3  11.828129  0979544114      5.0
# 5      242874                3  11.528156  9706061371      5.0
# 6      242874                3  11.528156  9706061371      5.0
# 7      242874                3  11.528156  9706061371      5.0
# 8      242874                3  11.528156  9706061371      5.0
# 9      242874                3  11.528156  9706061371      5.0
# 10     242874                3  11.528156  9706061371      5.0
# 11     242874                3  11.528156  9706061371      5.0
# 12     242290                3  11.388134  9706061185      5.0
# 13     242290                3  11.388134  9706061185      5.0
# 14     242290                3  11.388134  9706061185      5.0
# 15     242290                3  11.388134  9706061185      5.0
# 16     242290                3  11.388134  9706061185      5.0
# 17     242290                3  11.388134  9706061185      5.0
# 18     242290                3  11.388134  9706061185      5.0
# 19     360592                3  11.358866  9706060863      5.0
# 20     360592                3  11.358866  9706060863      5.0
# 21     360592                3  11.358866  9706060863      5.0
# 22     360592                3  11.358866  9706060863      5.0
# 23     360592                3  11.358866  9706060863      5.0
# 24     253057                3  11.552154  9706061061      5.0
# 25     253057                3  11.552154  9706061061      5.0
# 26     253057                3  11.552154  9706061061      5.0
# 27     253057                3  11.552154  9706061061      5.0
# 28     253057                3  11.552154  9706061061      5.0
# 29     253057                3  11.552154  9706061061      5.0
# 30     253057                3  11.552154  9706061061      5.0
# 31     358483                3  11.682208  9685368341      5.0
# 32     358483                3  11.682208  9685368341      5.0
# 33     358483                3  11.682208  9685368341      5.0
# 34     358483                3  11.682208  9685368341      5.0
# 35     358483                3  11.682208  9685368341      5.0
# 36     294762                3  11.695086  9686636412      5.0
# 37     294762                3  11.695086  9686636412      5.0
# 38     294762                3  11.695086  9686636412      5.0
# 39     294762                3  11.695086  9686636412      5.0
# 40     294762                3  11.695086  9686636412      5.0
# 41     294762                3  11.695086  9686636412      5.0
#
#         reviewerID                                           category  \
# 0   A3NBC5OFMFP2MS                 [Books, Children's Books, Animals]
# 1   A22Y8RL2DOA57T                 [Books, Children's Books, Animals]
# 2   A105Q3YYDW6HQ1                 [Books, Children's Books, Animals]
# 3    AG8DPYVTLT2C2                 [Books, Children's Books, Animals]
# 4    A3Z9QN0RCOHEY                 [Books, Children's Books, Animals]
# 5   A1ZB0MH8DLW843                                 [Books, Self-Help]
# 6   A2D2TAWMGQJYCJ                                 [Books, Self-Help]
# 7   A2SZGIUKIIVDMS                                 [Books, Self-Help]
# 8   A2CSSHRXZC4EUH                                 [Books, Self-Help]
# 9    A7NZ2ELAMGYAC                                 [Books, Self-Help]
# 10  A19P2M6QX6JSN0                                 [Books, Self-Help]
# 11  A1OTEJ92VV9ZUQ                                 [Books, Self-Help]
# 12  A3SALPUNQY5H5V                      [Books, Self-Help, Happiness]
# 13  A2SZGIUKIIVDMS                      [Books, Self-Help, Happiness]
# 14  A2CSSHRXZC4EUH                      [Books, Self-Help, Happiness]
# 15   A7NZ2ELAMGYAC                      [Books, Self-Help, Happiness]
# 16   ACTBQZV1CJ9E8                      [Books, Self-Help, Happiness]
# 17  A19P2M6QX6JSN0                      [Books, Self-Help, Happiness]
# 18  A1OTEJ92VV9ZUQ                      [Books, Self-Help, Happiness]
# 19  A2SZGIUKIIVDMS                                                 []
# 20  A2CSSHRXZC4EUH                                                 []
# 21  A19P2M6QX6JSN0                                                 []
# 22  A3RQTKSCLTQ6G6                                                 []
# 23  A1OTEJ92VV9ZUQ                                                 []
# 24  A2DUHTNIICT49N                                                 []
# 25  A2SUEKJK933OP2                                                 []
# 26  A2SZGIUKIIVDMS                                                 []
# 27  A23UXP303YHG6R                                                 []
# 28  A19P2M6QX6JSN0                                                 []
# 29  A1OTEJ92VV9ZUQ                                                 []
# 30  A37M4GQ05NGGSM                                                 []
# 31  A1ZB0MH8DLW843  [Books, Cookbooks, Food & Wine, Regional & Int...
# 32  A2DJC9VAM2HCE3  [Books, Cookbooks, Food & Wine, Regional & Int...
# 33  A35BZWGN90NZUM  [Books, Cookbooks, Food & Wine, Regional & Int...
# 34  A2SZGIUKIIVDMS  [Books, Cookbooks, Food & Wine, Regional & Int...
# 35  A3EI9DJOLMOJRA  [Books, Cookbooks, Food & Wine, Regional & Int...
# 36  A2DUHTNIICT49N                                                 []
# 37  A30XZJVOTWEEMS                                                 []
# 38  A2D2TAWMGQJYCJ                                                 []
# 39  A2SZGIUKIIVDMS                                                 []
# 40   ACTBQZV1CJ9E8                                                 []
# 41  A1OTEJ92VV9ZUQ                                                 []
#
#                                                 price  \
# 0                                              $30.81
# 1                                              $30.81
# 2                                              $30.81
# 3                                              $30.81
# 4                                              $30.81
# 5   .a-section.a-spacing-mini{margin-bottom:6px!im...
# 6   .a-section.a-spacing-mini{margin-bottom:6px!im...
# 7   .a-section.a-spacing-mini{margin-bottom:6px!im...
# 8   .a-section.a-spacing-mini{margin-bottom:6px!im...
# 9   .a-section.a-spacing-mini{margin-bottom:6px!im...
# 10  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 11  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 12  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 13  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 14  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 15  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 16  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 17  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 18  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 19                                             $15.80
# 20                                             $15.80
# 21                                             $15.80
# 22                                             $15.80
# 23                                             $15.80
# 24  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 25  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 26  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 27  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 28  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 29  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 30  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 31                                             $69.00
# 32                                             $69.00
# 33                                             $69.00
# 34                                             $69.00
# 35                                             $69.00
# 36                                            $275.00
# 37                                            $275.00
# 38                                            $275.00
# 39                                            $275.00
# 40                                            $275.00
# 41                                            $275.00
#
#                                                 title
# 0    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 1    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 2    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 3    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 4    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 5   C&oacute;mo vencer 5 errores que nos arruinan ...
# 6   C&oacute;mo vencer 5 errores que nos arruinan ...
# 7   C&oacute;mo vencer 5 errores que nos arruinan ...
# 8   C&oacute;mo vencer 5 errores que nos arruinan ...
# 9   C&oacute;mo vencer 5 errores que nos arruinan ...
# 10  C&oacute;mo vencer 5 errores que nos arruinan ...
# 11  C&oacute;mo vencer 5 errores que nos arruinan ...
# 12  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 13  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 14  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 15  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 16  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 17  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 18  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 19            Un Clavel en el Fango (Spanish Edition)
# 20            Un Clavel en el Fango (Spanish Edition)
# 21            Un Clavel en el Fango (Spanish Edition)
# 22            Un Clavel en el Fango (Spanish Edition)
# 23            Un Clavel en el Fango (Spanish Edition)
# 24                          Un Mundo Feliz: EL PROZAC
# 25                          Un Mundo Feliz: EL PROZAC
# 26                          Un Mundo Feliz: EL PROZAC
# 27                          Un Mundo Feliz: EL PROZAC
# 28                          Un Mundo Feliz: EL PROZAC
# 29                          Un Mundo Feliz: EL PROZAC
# 30                          Un Mundo Feliz: EL PROZAC
# 31  Men&uacute;s para Todo el A&ntilde;o ( Menus f...
# 32  Men&uacute;s para Todo el A&ntilde;o ( Menus f...
# 33  Men&uacute;s para Todo el A&ntilde;o ( Menus f...
# 34  Men&uacute;s para Todo el A&ntilde;o ( Menus f...
# 35  Men&uacute;s para Todo el A&ntilde;o ( Menus f...
# 36  Lo Mejor de la Superacin Personal ( The Best o...
# 37  Lo Mejor de la Superacin Personal ( The Best o...
# 38  Lo Mejor de la Superacin Personal ( The Best o...
# 39  Lo Mejor de la Superacin Personal ( The Best o...
# 40  Lo Mejor de la Superacin Personal ( The Best o...
# 41  Lo Mejor de la Superacin Personal ( The Best o...

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '101'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex    overall        asin  \
# 0     339877              101  10.608191  9706061126
# 1     324579              101  12.042072  0979544114
# 2     242874              101  10.771022  9706061371
# 3     242290              101  10.683022  9706061185
# 4     308060              101  10.722486  9686636617
# 5     360592              101  10.757002  9706060863
# 6     335568              101  10.667790  9706061614
# 7     253057              101  10.969269  9706061061
# 8     294762              101  11.023747  9686636412
#
#                              category  \
# 0                                  []
# 1  [Books, Children's Books, Animals]
# 2                  [Books, Self-Help]
# 3       [Books, Self-Help, Happiness]
# 4                                  []
# 5                                  []
# 6                                  []
# 7                                  []
# 8                                  []
#
#                                                price  \
# 0                                             $11.70
# 1                                             $30.81
# 2  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 3  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 4  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 5                                             $15.80
# 6
# 7  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 8                                            $275.00
#
#                                                title
# 0  A veces, Dios dice "NO!" (Sometimes, God says ...
# 1   Christmas at the Zoo: A Pop-Up Winter Wonderland
# 2  C&oacute;mo vencer 5 errores que nos arruinan ...
# 3  Amor A S&iacute; Mismo Despu&eacute;s de los 4...
# 4  Analice su Personalidad ( Analyze your Persona...
# 5            Un Clavel en el Fango (Spanish Edition)
# 6  Dietas Violentas para Valientes (Harsh Diets f...
# 7                          Un Mundo Feliz: EL PROZAC
# 8  Lo Mejor de la Superacin Personal ( The Best o...

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '134'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex    overall        asin  \
# 0     227642              134  11.518301  9687968257
# 1     188687              134  11.504252  9687968281
# 2     343863              134  11.708134  9686801693
# 3     257191              134  11.477867  9686801707
# 4     240691              134  11.491187  9706061789
# 5     245530              134  11.588929  9706061576
# 6     227242              134  11.516125  1857910478
# 7     274360              134  11.634775  9706061681
# 8     153367              134  11.535437  9706061908
# 9     188082              134  11.539589  9686801278
#
#                                             category  \
# 0                [Books, Politics & Social Sciences]
# 1                                                 []
# 2             [Books, Health, Fitness &amp; Dieting]
# 3  [Books, Health, Fitness &amp; Dieting, Women's...
# 4  [Books, Health, Fitness &amp; Dieting, Exercis...
# 5  [Books, Cookbooks, Food & Wine, Cooking Educat...
# 6     [Books, Reference, Dictionaries & Thesauruses]
# 7                                                 []
# 8  [Books, Literature &amp; Fiction, History &amp...
# 9  [Books, Cookbooks, Food &amp; Wine, Regional &...
#
#                                                price  \
# 0                                              $9.66
# 1                                             $45.98
# 2
# 3                                             $70.33
# 4
# 5  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 6                                             $16.60
# 7                                             $10.00
# 8                                             $29.95
# 9
#
#                                                title
# 0  El Derecho Prohibido...(A Baby:Forbiden Right)...
# 1  Antologa de Autoestima y Amor (The Best of Sel...
# 2                El estres es Vida (Spanish Edition)
# 3        Libro de Oro del Embarazo (Spanish Edition)
# 4  Ejercicios Isomtricos (Isometric Exercises) (S...
# 5  Cocina Mexicana de los siglos XVI al XIX ( Mex...
# 6  Focloir Poca: English-Irish Irish-English Dict...
# 7  Dios Mio ! &iexcl;Hazme Delgada!( Oh,Lord, Mak...
# 8  La Leona de Mxico (Mexico`s Lioness) (Spanish ...
# 9             Cocina para celebrar (Spanish Edition)

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '584'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex    overall        asin  \
# 0     188687              584  10.210522  9687968281
# 1     260682              584  10.316936  9706061193
# 2     257191              584  10.299189  9686801707
# 3     362007              584  10.584541  9687968222
# 4     281154              584  10.186992  9706060480
# 5     197354              584  10.245995  9686801758
# 6     188082              584  10.328151  9686801278
#
#                                             category  \
# 0                                                 []
# 1  [Books, Health, Fitness & Dieting, Women's Hea...
# 2  [Books, Health, Fitness &amp; Dieting, Women's...
# 3  [Books, Health, Fitness & Dieting, Psychology ...
# 4                    [Books, Self-Help, Self-Esteem]
# 5  [Books, Religion &amp; Spirituality, New Age &...
# 6  [Books, Cookbooks, Food &amp; Wine, Regional &...
#
#                                                price  \
# 0                                             $45.98
# 1  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 2                                             $70.33
# 3
# 4
# 5                                            $125.43
# 6
#
#                                                title
# 0  Antologa de Autoestima y Amor (The Best of Sel...
# 1  &iexcl;Lo que no Fue!:&iquest;Era tu Criatura?...
# 2        Libro de Oro del Embarazo (Spanish Edition)
# 3       Tests de Amor y Sexualidad (Spanish Edition)
# 4  Amor A S Mismo : La Clave Dinmica de la Felicidad
# 5  Ultimas Profecas Y Revelaciones Para El Tercer...
# 6             Cocina para celebrar (Spanish Edition)

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '300'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex   overall        asin  \
# 0     366581              300  9.464398  9706061312
# 1     227642              300  9.452726  9687968257
# 2     343863              300  9.757562  9686801693
# 3     311108              300  9.628062  968663620X
# 4     185439              300  9.456269  9706060375
# 5     274360              300  9.643435  9706061681
# 6     347860              300  9.677858  9686801626
# 7     188082              300  9.670881  9686801278
# 8     309686              300  9.638183  9686801766
# 9     267975              300  9.535411  968680188X
#
#                                             category  \
# 0  [Books, Reference, Foreign Language Study &amp...
# 1                [Books, Politics & Social Sciences]
# 2             [Books, Health, Fitness &amp; Dieting]
# 3  [Books, Reference, Foreign Language Study &amp...
# 4  [Books, Health, Fitness & Dieting, Diseases & ...
# 5                                                 []
# 6                                                 []
# 7  [Books, Cookbooks, Food &amp; Wine, Regional &...
# 8                                                 []
# 9                  [Books, Self-Help, Relationships]
#
#                                                price  \
# 0                                             $14.46
# 1                                              $9.66
# 2
# 3
# 4
# 5                                             $10.00
# 6  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 7
# 8                                             $20.99
# 9
#
#                                                title
# 0                         La Cruda (Spanish Edition)
# 1  El Derecho Prohibido...(A Baby:Forbiden Right)...
# 2                El estres es Vida (Spanish Edition)
# 3  Hable Ingles Facilmente (Learn English Easily)...
# 4       Sindrome de Fatiga Cronica (Spanish Edition)
# 5  Dios Mio ! &iexcl;Hazme Delgada!( Oh,Lord, Mak...
# 6                  Genio e Ingenio (Spanish Edition)
# 7             Cocina para celebrar (Spanish Edition)
# 8               Gimnasia emocional (Spanish Edition)
# 9                             El Libro del BUEN AMOR

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '149'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex    overall        asin  \
# 0     227642              149  11.363262  9687968257
# 1     188687              149  10.936651  9687968281
# 2     326409              149  11.072326  9687968516
# 3     240691              149  10.925278  9706061789
# 4     245530              149  10.902111  9706061576
# 5     204980              149  11.341427  9687968141
# 6     209640              149  11.364800  9706061711
# 7     229039              149  10.931799  9686636307
# 8     274360              149  11.012180  9706061681
# 9     153367              149  11.044093  9706061908
#
#                                             category  \
# 0                [Books, Politics & Social Sciences]
# 1                                                 []
# 2  [Books, Parenting &amp; Relationships, Parenting]
# 3  [Books, Health, Fitness &amp; Dieting, Exercis...
# 4  [Books, Cookbooks, Food & Wine, Cooking Educat...
# 5                                                 []
# 6      [Books, Cookbooks, Food & Wine, Special Diet]
# 7  [Books, New, Used &amp; Rental Textbooks, Huma...
# 8                                                 []
# 9  [Books, Literature &amp; Fiction, History &amp...
#
#                                                price  \
# 0                                              $9.66
# 1                                             $45.98
# 2                                             $12.95
# 3
# 4  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 5
# 6
# 7
# 8                                             $10.00
# 9                                             $29.95
#
#                                                title
# 0  El Derecho Prohibido...(A Baby:Forbiden Right)...
# 1  Antologa de Autoestima y Amor (The Best of Sel...
# 2  Juegos de Talento para tu Hijo (Talent games f...
# 3  Ejercicios Isomtricos (Isometric Exercises) (S...
# 4  Cocina Mexicana de los siglos XVI al XIX ( Mex...
# 5                                  El Gozo del Perdn
# 6  Noventa Recetas para Prevenir el C&aacute;ncer...
# 7    Ingls en un mes (sin maestro) (Spanish Edition)
# 8  Dios Mio ! &iexcl;Hazme Delgada!( Oh,Lord, Mak...
# 9  La Leona de Mxico (Mexico`s Lioness) (Spanish ...

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '142'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex    overall        asin  \
# 0     188687              142  11.490227  9687968281
# 1     343863              142  11.692266  9686801693
# 2     257191              142  11.486545  9686801707
# 3     240691              142  11.455630  9706061789
# 4     311108              142  11.469636  968663620X
# 5     245530              142  11.451735  9706061576
# 6     362007              142  11.750139  9687968222
# 7     274360              142  11.463840  9706061681
# 8     153367              142  11.544732  9706061908
# 9     188082              142  11.756474  9686801278
#
#                                             category  \
# 0                                                 []
# 1             [Books, Health, Fitness &amp; Dieting]
# 2  [Books, Health, Fitness &amp; Dieting, Women's...
# 3  [Books, Health, Fitness &amp; Dieting, Exercis...
# 4  [Books, Reference, Foreign Language Study &amp...
# 5  [Books, Cookbooks, Food & Wine, Cooking Educat...
# 6  [Books, Health, Fitness & Dieting, Psychology ...
# 7                                                 []
# 8  [Books, Literature &amp; Fiction, History &amp...
# 9  [Books, Cookbooks, Food &amp; Wine, Regional &...
#
#                                                price  \
# 0                                             $45.98
# 1
# 2                                             $70.33
# 3
# 4
# 5  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 6
# 7                                             $10.00
# 8                                             $29.95
# 9
#
#                                                title
# 0  Antologa de Autoestima y Amor (The Best of Sel...
# 1                El estres es Vida (Spanish Edition)
# 2        Libro de Oro del Embarazo (Spanish Edition)
# 3  Ejercicios Isomtricos (Isometric Exercises) (S...
# 4  Hable Ingles Facilmente (Learn English Easily)...
# 5  Cocina Mexicana de los siglos XVI al XIX ( Mex...
# 6       Tests de Amor y Sexualidad (Spanish Edition)
# 7  Dios Mio ! &iexcl;Hazme Delgada!( Oh,Lord, Mak...
# 8  La Leona de Mxico (Mexico`s Lioness) (Spanish ...
# 9             Cocina para celebrar (Spanish Edition)

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '99'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex    overall        asin  \
# 0     331096               99  11.996804  B00H006TZS
# 1     260682               99  11.788243  9706061193
# 2     264383               99  11.805550  968536804X
# 3     343863               99  11.994937  9686801693
# 4     257191               99  11.923459  9686801707
# 5     311108               99  11.787640  968663620X
# 6     185439               99  11.805047  9706060375
# 7     347860               99  12.058932  9686801626
# 8     188082               99  12.056048  9686801278
# 9     267975               99  11.805303  968680188X
#
#                                             category  \
# 0  [Books, Parenting & Relationships, Family Rela...
# 1  [Books, Health, Fitness & Dieting, Women's Hea...
# 2                                                 []
# 3             [Books, Health, Fitness &amp; Dieting]
# 4  [Books, Health, Fitness &amp; Dieting, Women's...
# 5  [Books, Reference, Foreign Language Study &amp...
# 6  [Books, Health, Fitness & Dieting, Diseases & ...
# 7                                                 []
# 8  [Books, Cookbooks, Food &amp; Wine, Regional &...
# 9                  [Books, Self-Help, Relationships]
#
#                                                price  \
# 0
# 1  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 2                                             $23.96
# 3
# 4                                             $70.33
# 5
# 6
# 7  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 8
# 9
#
#                                                title
# 0                      Emotional Abusive In Marriage
# 1  &iexcl;Lo que no Fue!:&iquest;Era tu Criatura?...
# 2               Amor a si mismo y A Los Dem&agrave;s
# 3                El estres es Vida (Spanish Edition)
# 4        Libro de Oro del Embarazo (Spanish Edition)
# 5  Hable Ingles Facilmente (Learn English Easily)...
# 6       Sindrome de Fatiga Cronica (Spanish Edition)
# 7                  Genio e Ingenio (Spanish Edition)
# 8             Cocina para celebrar (Spanish Edition)
# 9                             El Libro del BUEN AMOR

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '148'").toPandas()
# Out:
#     asinIndex  reviewerIDIndex    overall        asin  overall  \
# 0      324579              148  11.239884  0979544114      5.0
# 1      324579              148  11.239884  0979544114      5.0
# 2      324579              148  11.239884  0979544114      5.0
# 3      324579              148  11.239884  0979544114      5.0
# 4      324579              148  11.239884  0979544114      5.0
# 5      316419              148  10.264614  0688112161      5.0
# 6      316419              148  10.264614  0688112161      5.0
# 7      316419              148  10.264614  0688112161      5.0
# 8      316419              148  10.264614  0688112161      5.0
# 9      316419              148  10.264614  0688112161      5.0
# 10     360592              148  10.291299  9706060863      5.0
# 11     360592              148  10.291299  9706060863      5.0
# 12     360592              148  10.291299  9706060863      5.0
# 13     360592              148  10.291299  9706060863      5.0
# 14     360592              148  10.291299  9706060863      5.0
# 15     253057              148  10.318841  9706061061      5.0
# 16     253057              148  10.318841  9706061061      5.0
# 17     253057              148  10.318841  9706061061      5.0
# 18     253057              148  10.318841  9706061061      5.0
# 19     253057              148  10.318841  9706061061      5.0
# 20     253057              148  10.318841  9706061061      5.0
# 21     253057              148  10.318841  9706061061      5.0
# 22     294762              148  10.652662  9686636412      5.0
# 23     294762              148  10.652662  9686636412      5.0
# 24     294762              148  10.652662  9686636412      5.0
# 25     294762              148  10.652662  9686636412      5.0
# 26     294762              148  10.652662  9686636412      5.0
# 27     294762              148  10.652662  9686636412      5.0
#
#         reviewerID                                           category  \
# 0   A3NBC5OFMFP2MS                 [Books, Children's Books, Animals]
# 1   A22Y8RL2DOA57T                 [Books, Children's Books, Animals]
# 2   A105Q3YYDW6HQ1                 [Books, Children's Books, Animals]
# 3    AG8DPYVTLT2C2                 [Books, Children's Books, Animals]
# 4    A3Z9QN0RCOHEY                 [Books, Children's Books, Animals]
# 5    AFEZZWNH0IWKV  [Books, Cookbooks, Food &amp; Wine, Regional &...
# 6   A1BDH156XG7Y86  [Books, Cookbooks, Food &amp; Wine, Regional &...
# 7   A1NIE1ASE0MEWX  [Books, Cookbooks, Food &amp; Wine, Regional &...
# 8   A2WO0NZL5ZXU7E  [Books, Cookbooks, Food &amp; Wine, Regional &...
# 9   A2HPQ2H97EKBCH  [Books, Cookbooks, Food &amp; Wine, Regional &...
# 10  A2SZGIUKIIVDMS                                                 []
# 11  A2CSSHRXZC4EUH                                                 []
# 12  A19P2M6QX6JSN0                                                 []
# 13  A3RQTKSCLTQ6G6                                                 []
# 14  A1OTEJ92VV9ZUQ                                                 []
# 15  A2DUHTNIICT49N                                                 []
# 16  A2SUEKJK933OP2                                                 []
# 17  A2SZGIUKIIVDMS                                                 []
# 18  A23UXP303YHG6R                                                 []
# 19  A19P2M6QX6JSN0                                                 []
# 20  A1OTEJ92VV9ZUQ                                                 []
# 21  A37M4GQ05NGGSM                                                 []
# 22  A2DUHTNIICT49N                                                 []
# 23  A30XZJVOTWEEMS                                                 []
# 24  A2D2TAWMGQJYCJ                                                 []
# 25  A2SZGIUKIIVDMS                                                 []
# 26   ACTBQZV1CJ9E8                                                 []
# 27  A1OTEJ92VV9ZUQ                                                 []
#
#                                                 price  \
# 0                                              $30.81
# 1                                              $30.81
# 2                                              $30.81
# 3                                              $30.81
# 4                                              $30.81
# 5                                              $13.68
# 6                                              $13.68
# 7                                              $13.68
# 8                                              $13.68
# 9                                              $13.68
# 10                                             $15.80
# 11                                             $15.80
# 12                                             $15.80
# 13                                             $15.80
# 14                                             $15.80
# 15  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 16  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 17  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 18  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 19  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 20  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 21  .a-section.a-spacing-mini{margin-bottom:6px!im...
# 22                                            $275.00
# 23                                            $275.00
# 24                                            $275.00
# 25                                            $275.00
# 26                                            $275.00
# 27                                            $275.00
#
#                                                 title
# 0    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 1    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 2    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 3    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 4    Christmas at the Zoo: A Pop-Up Winter Wonderland
# 5     Good Housekeeping Illustrated American Cookbook
# 6     Good Housekeeping Illustrated American Cookbook
# 7     Good Housekeeping Illustrated American Cookbook
# 8     Good Housekeeping Illustrated American Cookbook
# 9     Good Housekeeping Illustrated American Cookbook
# 10            Un Clavel en el Fango (Spanish Edition)
# 11            Un Clavel en el Fango (Spanish Edition)
# 12            Un Clavel en el Fango (Spanish Edition)
# 13            Un Clavel en el Fango (Spanish Edition)
# 14            Un Clavel en el Fango (Spanish Edition)
# 15                          Un Mundo Feliz: EL PROZAC
# 16                          Un Mundo Feliz: EL PROZAC
# 17                          Un Mundo Feliz: EL PROZAC
# 18                          Un Mundo Feliz: EL PROZAC
# 19                          Un Mundo Feliz: EL PROZAC
# 20                          Un Mundo Feliz: EL PROZAC
# 21                          Un Mundo Feliz: EL PROZAC
# 22  Lo Mejor de la Superacin Personal ( The Best o...
# 23  Lo Mejor de la Superacin Personal ( The Best o...
# 24  Lo Mejor de la Superacin Personal ( The Best o...
# 25  Lo Mejor de la Superacin Personal ( The Best o...
# 26  Lo Mejor de la Superacin Personal ( The Best o...
# 27  Lo Mejor de la Superacin Personal ( The Best o...

# %%
nrecommendations.join(books_meta_index_recommend, on='asinIndex').filter("reviewerIDIndex = '463'").toPandas()
# Out:
#    asinIndex  reviewerIDIndex   overall        asin  \
# 0      93338              463  9.947626  1495325814
# 1     330384              463  9.992572  8181462920
#
#                                            category  price  \
# 0  [Books, Arts &amp; Photography, Performing Arts]  $6.99
# 1                    [Books, Humor & Entertainment]
#
#                                                title
# 0  Sherlock Lives!: 100+ Facts on Sherlock and th...
# 1                 All About Nothing ( Hindi Edition)

# %%
books_index.select('reviewerID').show(10, truncate=False)
# Out:
# +---------------------+
# |reviewerID           |
# +---------------------+
# |A10000012B7CGYKOMPQ4L|
# |A2S166WSCFIFP5       |
# |A1BM81XB4QHOA3       |
# |A1MOSTXNIO5MPJ       |
# |A2XQ5LZHTD4AFT       |
# |A3V1MKC2BVWY48       |
# |A12387207U8U24       |
# |A29TRDMK51GKZR       |
# |A3FI0744PG1WYG       |
# |A2LBBQHYLEHM7P       |
# +---------------------+
# only showing top 10 rows

# %% [markdown]
# # User A10000012B7CGYKOMPQ4L Actual Preference:

# %%
books_index.join(Meta_Books_df, on='asin').filter("reviewerID == 'A10000012B7CGYKOMPQ4L'").sort('overall', ascending=False).limit(10).show()
# Out:
# +----------+-------+-------+--------------------+-----------+--------------------+------------+----------+--------------+---------+--------------------+------+--------------------+--------------------+
# |      asin|helpful|overall|          reviewText| reviewTime|          reviewerID|reviewerName|   summary|unixReviewTime|asinIndex|            category| price|               title|         description|
# +----------+-------+-------+--------------------+-----------+--------------------+------------+----------+--------------+---------+--------------------+------+--------------------+--------------------+
# |000100039X| [0, 0]|    5.0|Spiritually and m...|12 16, 2012|A10000012B7CGYKOM...|        Adam|Wonderful!|    1355616000|   4321.0|[Books, Literatur...|      |         The Prophet|[Kahlil Gibran wa...|
# |0446691437| [0, 0]|    5.0|Excellent book! I...|12 16, 2012|A10000012B7CGYKOM...|        Adam| So Great.|    1355616000|   1007.0|[Books, Health, F...|$26.25|The War of Art: B...|[Steven Pressfiel...|
# |0486274268| [0, 0]|    4.0|Informative, and ...|12 16, 2012|A10000012B7CGYKOM...|        Adam|    Great!|    1355616000|  65462.0|[Books, Arts &amp...|      |The Art of Animal...|            [, , , ]|
# |048622709X| [0, 1]|    4.0|A great book! A w...|12 16, 2012|A10000012B7CGYKOM...|        Adam|    Great!|    1355616000| 122429.0|[Books, Arts &amp...|$10.95|The Book of a Hun...|[, , Mr. Bridgman...|
# |0486404730| [0, 0]|    4.0|Wonderful and det...|12 16, 2012|A10000012B7CGYKOM...|        Adam|    Great!|    1355616000|  50186.0|[Books, Engineeri...|$10.95|Perspective Made ...|[, Perspective, t...|
# |0486227081| [0, 0]|    4.0|Great book of ref...|12 16, 2012|A10000012B7CGYKOM...|        Adam|    Great!|    1355616000| 319711.0|[Books, Arts &amp...| $6.95|Heads, Features a...|        [, , , , , ]|
# +----------+-------+-------+--------------------+-----------+--------------------+------------+----------+--------------+---------+--------------------+------+--------------------+--------------------+

# %%
Meta_Books_df_interpret = Meta_Books.select("asin","category",'price','title','description')
books_index_interpret = books1_index.select('asin','reviewerID','overall','reviewerIDIndex')

# %%
books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '3'").sort('overall', ascending=False).limit(10).toPandas()
# Out:
#          asin     reviewerID  overall  reviewerIDIndex  \
# 0  0061253758  A320TMDV6KCFU      5.0              3.0
# 1  0061456756  A320TMDV6KCFU      5.0              3.0
# 2  014314295X  A320TMDV6KCFU      5.0              3.0
# 3  0446502049  A320TMDV6KCFU      5.0              3.0
# 4  0451226518  A320TMDV6KCFU      5.0              3.0
# 5  0505527324  A320TMDV6KCFU      5.0              3.0
# 6  0975453386  A320TMDV6KCFU      5.0              3.0
# 7  141996920X  A320TMDV6KCFU      5.0              3.0
# 8  159998105X  A320TMDV6KCFU      5.0              3.0
# 9  160202054X  A320TMDV6KCFU      5.0              3.0
#
#                                            category   price  \
# 0      [Books, Literature & Fiction, United States]   $4.74
# 1      [Books, Literature & Fiction, United States]   $7.99
# 2      [Books, Literature & Fiction, Genre Fiction]  $11.79
# 3  [Books, Literature &amp; Fiction, United States]   $7.99
# 4                      [Books, Romance, Historical]
# 5  [Books, Literature &amp; Fiction, United States]  $11.97
# 6                      [Books, Romance, Historical]
# 7  [Books, Literature &amp; Fiction, United States]
# 8        [Books, Literature &amp; Fiction, Erotica]  $16.11
# 9        [Books, Literature &amp; Fiction, Erotica]
#
#                                          title  \
# 0          No One Left To Tell (No One Series)
# 1  Always a Scoundrel: The Notorious Gentlemen
# 2            The Seduction of the Crimson Rose
# 3       Addicted to Love (Wedding Veil Wishes)
# 4                           The Secret Wedding
# 5               Divorced, Desperate and Dating
# 6                                   Redemption
# 7                        Shadow (New Spiecies)
# 8                                  Loving Lies
# 9                               A Few Good Men
#
#                                          description
# 0  [&#34;Jordan Dane shows true brilliance with h...
# 1  [, A native and current resident of Southern C...
# 2  [<DIV>, Lauren Willig is a law student and Ph....
# 3  ["Entertaining and humorous...There's a seriou...
# 4  [Caro Hill mustdo one thing before she accepts...
# 5                                               [, ]
# 6  ["Morgan Leshay makes a promising debut-a beau...
# 7                                               [, ]
# 8                                           [, , , ]
# 9       [<b>The Red Hot &amp; Blue Series</b>, , , ]

# %%
df101 = books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '101'").sort('overall', ascending=False).limit(100).toPandas()

# %%
df101
# Out:
#           asin      reviewerID  overall  reviewerIDIndex  \
# 0   0006530699  A2HM0BZWQRV1EF      5.0            101.0
# 1   0440221048  A2HM0BZWQRV1EF      5.0            101.0
# 2   0967721318  A2HM0BZWQRV1EF      5.0            101.0
# 3   0061905267  A2HM0BZWQRV1EF      5.0            101.0
# 4   0451191137  A2HM0BZWQRV1EF      5.0            101.0
# 5   0143145088  A2HM0BZWQRV1EF      5.0            101.0
# 6   0471477532  A2HM0BZWQRV1EF      5.0            101.0
# 7   1577310721  A2HM0BZWQRV1EF      5.0            101.0
# 8   1612120512  A2HM0BZWQRV1EF      5.0            101.0
# 9   0802717780  A2HM0BZWQRV1EF      5.0            101.0
# 10  0307346625  A2HM0BZWQRV1EF      5.0            101.0
# 11  0307595609  A2HM0BZWQRV1EF      5.0            101.0
# 12  0061905283  A2HM0BZWQRV1EF      5.0            101.0
# 13  0446691801  A2HM0BZWQRV1EF      5.0            101.0
# 14  039306123X  A2HM0BZWQRV1EF      5.0            101.0
# 15  1591792037  A2HM0BZWQRV1EF      5.0            101.0
# 16  0615287484  A2HM0BZWQRV1EF      5.0            101.0
# 17  074356619X  A2HM0BZWQRV1EF      5.0            101.0
# 18  0316324469  A2HM0BZWQRV1EF      5.0            101.0
# 19  0684870754  A2HM0BZWQRV1EF      5.0            101.0
# 20  098589850X  A2HM0BZWQRV1EF      5.0            101.0
# 21  0316200808  A2HM0BZWQRV1EF      5.0            101.0
# 22  030726646X  A2HM0BZWQRV1EF      5.0            101.0
# 23  0307263649  A2HM0BZWQRV1EF      5.0            101.0
# 24  0375507477  A2HM0BZWQRV1EF      5.0            101.0
# 25  0974524573  A2HM0BZWQRV1EF      5.0            101.0
# 26  0446523674  A2HM0BZWQRV1EF      5.0            101.0
# 27  0312379080  A2HM0BZWQRV1EF      5.0            101.0
# 28  0446527793  A2HM0BZWQRV1EF      5.0            101.0
# 29  0060756632  A2HM0BZWQRV1EF      5.0            101.0
# ..         ...             ...      ...              ...
# 70  0060559284  A2HM0BZWQRV1EF      5.0            101.0
# 71  0446526762  A2HM0BZWQRV1EF      5.0            101.0
# 72  0615321364  A2HM0BZWQRV1EF      5.0            101.0
# 73  0609603906  A2HM0BZWQRV1EF      5.0            101.0
# 74  0679437096  A2HM0BZWQRV1EF      5.0            101.0
# 75  0743245911  A2HM0BZWQRV1EF      5.0            101.0
# 76  1401300340  A2HM0BZWQRV1EF      5.0            101.0
# 77  0071590730  A2HM0BZWQRV1EF      5.0            101.0
# 78  0446573124  A2HM0BZWQRV1EF      5.0            101.0
# 79  1608680738  A2HM0BZWQRV1EF      5.0            101.0
# 80  0446678333  A2HM0BZWQRV1EF      5.0            101.0
# 81  044900399X  A2HM0BZWQRV1EF      5.0            101.0
# 82  1930388179  A2HM0BZWQRV1EF      5.0            101.0
# 83  044655605X  A2HM0BZWQRV1EF      5.0            101.0
# 84  0060188219  A2HM0BZWQRV1EF      5.0            101.0
# 85  0983440514  A2HM0BZWQRV1EF      5.0            101.0
# 86  014305872X  A2HM0BZWQRV1EF      5.0            101.0
# 87  0446575038  A2HM0BZWQRV1EF      5.0            101.0
# 88  0451192613  A2HM0BZWQRV1EF      5.0            101.0
# 89  0547054017  A2HM0BZWQRV1EF      5.0            101.0
# 90  0743583078  A2HM0BZWQRV1EF      5.0            101.0
# 91  1402749996  A2HM0BZWQRV1EF      5.0            101.0
# 92  0316098752  A2HM0BZWQRV1EF      5.0            101.0
# 93  0786868252  A2HM0BZWQRV1EF      5.0            101.0
# 94  0470528494  A2HM0BZWQRV1EF      5.0            101.0
# 95  1400066158  A2HM0BZWQRV1EF      5.0            101.0
# 96  0060776625  A2HM0BZWQRV1EF      5.0            101.0
# 97  0345482433  A2HM0BZWQRV1EF      5.0            101.0
# 98  0446576433  A2HM0BZWQRV1EF      5.0            101.0
# 99  0446674265  A2HM0BZWQRV1EF      5.0            101.0
#
#                                              category   price  \
# 0   [Books, Business & Money, Processes & Infrastr...  $12.25
# 1   [Books, Mystery, Thriller & Suspense, Thriller...  $30.97
# 2   [Books, Health, Fitness &amp; Dieting, Alterna...  $19.95
# 3   [Books, Parenting &amp; Relationships, Family ...  $13.09
# 4    [Books, Literature &amp; Fiction, Genre Fiction]   $6.52
# 5     [Books, Business &amp; Money, Business Culture]  $18.00
# 6   [Books, Reference, Writing, Research &amp; Pub...
# 7   [Books, Health, Fitness &amp; Dieting, Psychol...  $17.00
# 8   [Books, Cookbooks, Food & Wine, Beverages & Wine]  $14.95
# 9         [Books, Sports &amp; Outdoors, Biographies]  $18.50
# 10                      [Books, Self-Help, Happiness]  $29.99
# 11  [Books, Biographies & Memoirs, Arts & Literature]  $11.03
# 12  [Books, Parenting &amp; Relationships, Family ...   $7.99
# 13    [Books, Business &amp; Money, Personal Finance]  $23.37
# 14  [Books, Biographies &amp; Memoirs, Ethnic &amp...   $6.99
# 15  [Books, Religion &amp; Spirituality, New Age &...  $14.38
# 16           [Books, Business &amp; Money, Investing]
# 17  [Books, Cookbooks, Food &amp; Wine, Entertaini...  $15.49
# 18       [Books, Literature & Fiction, Genre Fiction]  $13.49
# 19                  [Books, Self-Help, Relationships]  $18.20
# 20    [Books, Biographies & Memoirs, Specific Groups]
# 21             [Books, Arts &amp; Photography, Music]
# 22  [Books, Biographies &amp; Memoirs, Arts &amp; ...   $6.58
# 23  [Books, Computers &amp; Technology, Networking...   $5.99
# 24  [Books, Politics &amp; Social Sciences, Social...   $5.88
# 25  [Books, Christian Books & Bibles, Worship & De...  $16.95
# 26  [Books, Politics & Social Sciences, Social Sci...  $29.99
# 27  [Books, Mystery, Thriller &amp; Suspense, Thri...  $20.20
# 28    [Books, Literature &amp; Fiction, Contemporary]  $11.00
# 29  [Books, Crafts, Hobbies &amp; Home, Pets &amp;...
# ..                                                ...     ...
# 70                         [Books, History, Americas]   $2.96
# 71          [Books, Humor &amp; Entertainment, Humor]  $16.33
# 72  [Books, Health, Fitness &amp; Dieting, Diets &...  $10.88
# 73  [Books, Health, Fitness &amp; Dieting, Alterna...  $16.76
# 74             [Books, Humor & Entertainment, Movies]  $10.83
# 75            [Books, Sports & Outdoors, Biographies]  $26.07
# 76  [Books, Business &amp; Money, Marketing &amp; ...  $14.45
# 77                         [Books, History, Americas]  $16.82
# 78  [Books, Politics &amp; Social Sciences, Social...  $19.44
# 79  [Books, Health, Fitness &amp; Dieting, Psychol...  $12.00
# 80  [Books, Business &amp; Money, Marketing &amp; ...  $13.03
# 81  [Books, Mystery, Thriller &amp; Suspense, Thri...   $7.99
# 82                        [Books, Self-Help, Success]   $7.24
# 83  [Books, Business &amp; Money, Management &amp;...  $14.90
# 84  [Books, Biographies &amp; Memoirs, Arts &amp; ...  $10.00
# 85  [Books, Business &amp; Money, Management &amp;...  $15.95
# 86  [Books, Politics & Social Sciences, Social Sci...  $19.95
# 87                  [Books, Self-Help, Relationships]  $14.44
# 88  [Books, Mystery, Thriller &amp; Suspense, Thri...
# 89       [Books, Literature & Fiction, United States]   $9.25
# 90        [Books, Business & Money, Business Culture]  $21.98
# 91                   [Books, Self-Help, Motivational]   $5.00
# 92  [Books, Biographies &amp; Memoirs, Leaders &am...  $15.29
# 93  [Books, Business &amp; Money, Small Business &...  $15.84
# 94             [Books, Business &amp; Money, Finance]  $28.50
# 95              [Books, Self-Help, Death &amp; Grief]  $17.90
# 96        [Books, Business & Money, Business Culture]   $7.89
# 97  [Books, Health, Fitness &amp; Dieting, Psychol...  $12.98
# 98  [Books, Politics &amp; Social Sciences, Politi...  $11.88
# 99                  [Books, Self-Help, Relationships]   $7.99
#
#                                                 title  \
# 0   Raving Fans : Revolutionary Approach to Custom...
# 1                     A Certain Justice (Abe Glitsky)
# 2            Lyme Disease and Modern Chinese Medicine
# 3                              Heroes for My Daughter
# 4                                              Anthem
# 5   Drive: The Surprising Truth About What Motivat...
# 6   Edward R. Murrow and the Birth of Broadcast Jo...
# 7      Small Graces: The Quiet Gifts of Everyday Life
# 8   The Fresh Honey Cookbook: 84 Recipes from a Be...
# 9            Bill Veeck: Baseball's Greatest Maverick
# 10  Become Who You Were Born to Be: We All Have a ...
# 11          I Remember Nothing: and Other Reflections
# 12                                  Heroes for My Son
# 13  Rich Dad's Success Stories: Real Life Success ...
# 14                The Blind Side: Evolution of a Game
# 15  Finding Faith in Difficult Times: Teachings an...
# 16  Why Are We So Clueless about the Stock Market?...
# 17                  The Secret (Unabridged, 4-CD Set)
# 18                                  Disgraced: A Play
# 19  Life Lessons: Two Experts on Death and Dying T...
# 20  Blind Curves: &nbsp;One Woman's Unusual Journe...
# 21                            The John Lennon Letters
# 22                                 Audition: A Memoir
# 23  Send: The Essential Guide to Email for Office ...
# 24                          A Song Flung Up to Heaven
# 25  Everything Starts From Prayer: Mother Teresa's...
# 26  Martin Luther King, Jr., on Leadership: Inspir...
# 27                             Vanished (Nick Heller)
# 28                    The Guardian (Sparks, Nicholas)
# 29                                         Cat People
# ..                                                ...
# 70  Off with Their Heads: Traitors, Crooks &amp; O...
# 71  I'd Rather Laugh: How to Be Happy Even When Li...
# 72         Why Diet and Exercise Fail, Second Edition
# 73  Golf for Enlightenment: The Seven Lessons for ...
# 74                                      Making Movies
# 75     Luckiest Man: The Life and Death of Lou Gehrig
# 76  Hug Your Customers: The Proven Way to Personal...
# 77  Management Lessons from Mayo Clinic: Inside On...
# 78           Man Made: A Stupid Quest for Masculinity
# 79          Brain Power: Improve Your Mind as You Age
# 80  Rich Dad Advisor's Series: SalesDogs: You Do N...
# 81                               The Defense: A Novel
# 82                               Unexpected Treasures
# 83  Get Rid of the Performance Review!: How Compan...
# 84          Ask Me Again Tomorrow: A Life in Progress
# 85        Creatively Ever After: A Path to Innovation
# 86     Don't Make a Black Woman Take Off Her Earrings
# 87  Working It Out: A Journey of Love, Loss, and Hope
# 88                               Irresistible Impulse
# 89                    Dear American Airlines: A Novel
# 90  Peaks and Valleys: Making Good and Bad Times W...
# 91  Learning from the Heart: Lessons on Living, Lo...
# 92                                         The Obamas
# 93  How to Make Big Money In Your Own Small Busine...
# 94                          The Elements of Investing
# 95                                        About Alice
# 96  You Can't Win a Fight with Your Boss: &amp; 55...
# 97  CrazyBusy: Overstretched, Overbooked, and Abou...
# 98  Republic, Lost: How Money Corrupts Congress--a...
# 99  What Do I Say Next?: Talking Your Way to Busin...
#
#                                           description
# 0   [With a new foreword by Ken Blanchard A straig...
# 1   [&quot;Catapults Lescroart into the top ranks ...
# 2   [This is a comprehensive book on the cause and...
# 3   [, An inspiring collection of heroes from whom...
# 4   [Born February 2, 1905, <b>Ayn Rand</b> publis...
# 5   ["Pink makes a convincing case that organizati...
# 6   [Edwards, who has hosted NPR's <i>Morning Edit...
# 7                                                [, ]
# 8   [<DIV><P>Honey through the seasons</P><P></P><...
# 9   [, Veeck was a one of a kind whose impact reac...
# 10  [Americans are going through a crisis of ident...
# 11  [Reading these succinct, razor-sharp essays by...
# 12  [<span class="h1"><strong>Questions for Brad M...
# 13  [The Rich Dad series, begun in 1997, is based ...
# 14  [<i>Starred Review.</i> As he did so memorably...
# 15  [<b>Iyanla Vanzant</b><br />, Iyanla Vanzant h...
# 16  [Most people work hard for their money, and it...
# 17  [Supporters will hail this New Age self-help b...
# 18  ["The best play I saw last year.... [a] quick-...
# 19  [Patricia Devine <i>The Irish Independent</i> ...
# 20                                                 []
# 21  ["[Davies] has done a sensitive and scrupulous...
# 22  [*Starred Review* Audition might seem an odd t...
# 23  [<b><a href="http://www.amazon.com/exec/obidos...
# 24  [It's been a long time coming, but <i>A Song F...
# 25                                                 []
# 26  [Leadership motivational speaker Donald T. Phi...
# 27  [<b>Book Description</b><br />Nick Heller is t...
# 28  [On Christmas Eve, Julie Barenson, 25 years ol...
# 29  [Michael Korda, Simon &amp; Schuster's editor-...
# ..                                                ...
# 70  [Dick Morris is on a tirade in <i>Off With The...
# 71  [Remember "Coffee Talk," the <i>Saturday Night...
# 72                                               [, ]
# 73  [Chopra turns his mind-body eye on golf, a rec...
# 74  [Award-winning director Lumet (Dog Day Afterno...
# 75  [Lou Gehrig started his professional baseball ...
# 76  [If you work at a Fortune 500 company and live...
# 77  [, <b>Prescriptions for Service Success</b>, Q...
# 78  [When 38-year-old, self-confessed unmanly man ...
# 79                                       [, , , , , ]
# 80  [Blair Singer is a Corporate Educator, Facilit...
# 81  [Dynamite defense attorney Joseph Antonelli ha...
# 82                                               [, ]
# 83  [With clear, straightforward (and sometimes pr...
# 84  [Who can forget Rose Castorini, the feisty Ita...
# 85                                               [, ]
# 86  [Tyler Perry is a playwright, producer, direct...
# 87  ["Abby Rike's story is not easy to wrap your m...
# 88                                               [, ]
# 89  [<b>Elizabeth Gilbert on <i>Dear American Airl...
# 90  [John Dossett's crisp and polished delivery is...
# 91  [Starred Review. You have to love a self-help ...
# 92  ["'The strengths and challenges of our marriag...
# 93  [Once again, Fox gets his business expressed j...
# 94  [, In his classic book The Elements of Style, ...
# 95  [Trillin (<i>A Heckuva Job: More of the Bush A...
# 96  [Drawing on 20 years of experience with such c...
# 97  [Hallowell (Driven to Distraction; Delivered f...
# 98  [, , Lawrence Lessig is the Roy L. Furman Prof...
# 99                                               [, ]
#
# [100 rows x 8 columns]

# %%
df101['category'].astype('str').value_counts()
# Out:
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Thrillers &amp; Suspense']      6
# ['Books', 'Business &amp; Money', 'Management &amp; Leadership']               5
# ['Books', 'Business &amp; Money', 'Business Culture']                          5
# ['Books', 'Self-Help', 'Relationships']                                        4
# ['Books', 'Politics &amp; Social Sciences', 'Politics &amp; Government']       3
# ['Books', 'Health, Fitness &amp; Dieting', 'Psychology &amp; Counseling']      3
# ['Books', 'Biographies &amp; Memoirs', 'Arts &amp; Literature']                3
# ['Books', 'Business & Money', 'Skills']                                        2
# ['Books', 'Self-Help', 'Happiness']                                            2
# ['Books', 'Parenting &amp; Relationships', 'Family Relationships']             2
# ['Books', 'Politics & Social Sciences', 'Social Sciences']                     2
# ['Books', 'Humor & Entertainment', 'Humor']                                    2
# ['Books', 'Health, Fitness &amp; Dieting', 'Alternative Medicine']             2
# ['Books', 'Biographies &amp; Memoirs', 'Leaders &amp; Notable People']         2
# ['Books', 'Business &amp; Money', 'Job Hunting &amp; Careers']                 2
# ['Books', 'Politics &amp; Social Sciences', 'Social Sciences']                 2
# ['Books', 'Business & Money', 'Business Culture']                              2
# ['Books', 'Business &amp; Money', 'Marketing &amp; Sales']                     2
# ['Books', 'Mystery, Thriller & Suspense', 'Thrillers & Suspense']              2
# ['Books', 'History', 'Americas']                                               2
# ['Books', 'Reference', 'Writing, Research &amp; Publishing Guides']            2
# ['Books', 'Literature &amp; Fiction', 'Genre Fiction']                         1
# ['Books', 'Humor & Entertainment', 'Movies']                                   1
# ['Books', 'Politics & Social Sciences', 'Politics & Government']               1
# ['Books', 'Business & Money', 'Management & Leadership']                       1
# ['Books', 'Sports & Outdoors', 'Biographies']                                  1
# ['Books', 'Health, Fitness &amp; Dieting', 'Diets &amp; Weight Loss']          1
# ['Books', 'Sports &amp; Outdoors', 'Biographies']                              1
# ['Books', 'Business &amp; Money', 'Skills']                                    1
# ['Books', 'Biographies & Memoirs', 'Leaders & Notable People']                 1
#                                                                               ..
# ['Books', 'Cookbooks, Food & Wine', 'Beverages & Wine']                        1
# ['Books', 'Business &amp; Money', 'Investing']                                 1
# ['Books', 'Crafts, Hobbies &amp; Home', 'Home Improvement &amp; Design']       1
# ['Books', 'Christian Books & Bibles', 'Worship & Devotion']                    1
# ['Books', 'Humor &amp; Entertainment', 'Humor']                                1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Entertaining &amp; Holidays']         1
# ['Books', 'Literature &amp; Fiction', 'United States']                         1
# ['Books', 'Literature &amp; Fiction', 'History &amp; Criticism']               1
# ['Books', 'Religion &amp; Spirituality', 'New Age &amp; Spirituality']         1
# ['Books', 'Business &amp; Money', 'Personal Finance']                          1
# ['Books', 'Biographies & Memoirs', 'Arts & Literature']                        1
# ['Books', 'Literature & Fiction', 'United States']                             1
# ['Books', 'Self-Help', 'Motivational']                                         1
# ['Books', 'Self-Help', 'Success']                                              1
# ['Books', 'Arts &amp; Photography', 'Music']                                   1
# ['Books', 'Business &amp; Money', 'Small Business &amp; Entrepreneurship']     1
# ['Books', 'Business &amp; Money', 'Finance']                                   1
# ['Books', 'Health, Fitness & Dieting', 'Exercise & Fitness']                   1
# ['Books', 'Self-Help', 'Death &amp; Grief']                                    1
# ['Books', 'Business & Money', 'Job Hunting & Careers']                         1
# ['Books', 'Business &amp; Money', 'Processes &amp; Infrastructure']            1
# ['Books', 'Education &amp; Teaching', 'Schools &amp; Teaching']                1
# ['Books', 'Literature &amp; Fiction', 'Contemporary']                          1
# ['Books', 'Self-Help', 'Personal Transformation']                              1
# ['Books', 'Christian Books &amp; Bibles', 'Christian Living']                  1
# ['Books', 'Crafts, Hobbies &amp; Home', 'Pets &amp; Animal Care']              1
# ['Books', 'Biographies & Memoirs', 'Specific Groups']                          1
# ['Books', 'Literature & Fiction', 'Genre Fiction']                             1
# ['Books', 'Computers &amp; Technology', 'Networking &amp; Cloud Computing']    1
# ['Books', 'Business & Money', 'Processes & Infrastructure']                    1
# Name: category, Length: 64, dtype: int64

# %%
df134 = books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '134'").sort('overall', ascending=False).limit(100).toPandas()

# %%
df134['category'].astype('str').value_counts()
# Out:
# ['Books', 'Literature &amp; Fiction', 'Genre Fiction']                             14
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Thrillers &amp; Suspense']          11
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Mystery']                            7
# ['Books', 'Science &amp; Math', 'Biological Sciences']                              7
# ['Books', 'Cookbooks, Food &amp; Wine', 'Regional &amp; International']             7
# ['Books', 'Literature & Fiction', 'Genre Fiction']                                  6
# ['Books', 'Mystery, Thriller & Suspense', 'Mystery']                                4
# ['Books', 'Literature &amp; Fiction', 'United States']                              3
# ['Books', 'Cookbooks, Food &amp; Wine', 'Cooking Education &amp; Reference']        3
# ['Books', 'Literature &amp; Fiction', 'Contemporary']                               3
# ['Books', 'Mystery, Thriller & Suspense', 'Thrillers & Suspense']                   3
# ['Books', 'Humor &amp; Entertainment', 'Humor']                                     2
# ['Books', 'Biographies &amp; Memoirs', 'Arts &amp; Literature']                     2
# ['Books', 'Medical Books', 'Medicine']                                              2
# ['Books', 'Humor & Entertainment', 'Humor']                                         2
# ['Books', 'Literature & Fiction', 'United States']                                  1
# ['Books', 'Literature &amp; Fiction', 'World Literature']                           1
# ['Books', 'Cookbooks, Food & Wine', 'Cooking by Ingredient']                        1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Baking']                                   1
# ['Books', 'Cookbooks, Food & Wine', 'Cooking Education & Reference']                1
# ['Books', 'Arts &amp; Photography', 'Photography &amp; Video']                      1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Special Diet']                             1
# ['Books', 'Biographies &amp; Memoirs', 'Historical']                                1
# ['Books', 'Literature &amp; Fiction', 'Short Stories &amp; Anthologies']            1
# ['Books', 'Crafts, Hobbies &amp; Home', 'Gardening &amp; Landscape Design']         1
# ['Books', 'Cookbooks, Food & Wine', 'Regional & International']                     1
# ['Books', 'Arts & Photography', 'Drawing']                                          1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Outdoor Cooking']                          1
# ['Books', 'Science Fiction & Fantasy', 'Fantasy']                                   1
# ['Books', 'Humor &amp; Entertainment', 'Puzzles &amp; Games']                       1
# ['Books', 'Literature &amp; Fiction', 'Literary']                                   1
# ['Books', 'New, Used &amp; Rental Textbooks', 'Medicine &amp; Health Sciences']     1
# ['Books', 'Biographies & Memoirs', 'Arts & Literature']                             1
# ['Books', 'Literature & Fiction', 'Literary']                                       1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Cooking by Ingredient']                    1
# ['Books', 'Cookbooks, Food & Wine', 'Cooking Methods']                              1
# ['Books', 'Biographies &amp; Memoirs', 'Professionals &amp; Academics']             1
# ['Books', 'Crafts, Hobbies &amp; Home', 'Pets &amp; Animal Care']                   1
# ['Books', 'Business &amp; Money', 'Management &amp; Leadership']                    1
# Name: category, dtype: int64

# %%
df584 = books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '584'").sort('overall', ascending=False).limit(100).toPandas()

# %%
df584['category'].astype('str').value_counts()
# Out:
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Thrillers &amp; Suspense']         14
# ['Books', 'Literature &amp; Fiction', 'Genre Fiction']                            10
# ['Books', 'Literature & Fiction', 'Genre Fiction']                                 9
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Mystery']                           7
# ['Books', 'Mystery, Thriller & Suspense', 'Mystery']                               4
# ['Books', 'Mystery, Thriller & Suspense', 'Thrillers & Suspense']                  4
# ['Books', 'Politics &amp; Social Sciences', 'Politics &amp; Government']           4
# ['Books', 'Science Fiction &amp; Fantasy', 'Fantasy']                              3
# ['Books', 'Literature &amp; Fiction', 'Literary']                                  2
# ['Books', 'New, Used &amp; Rental Textbooks', 'Humanities']                        2
# ['Books', 'Literature & Fiction', 'Action & Adventure']                            2
# ['Books', 'Teen &amp; Young Adult', 'Literature &amp; Fiction']                    2
# ['Books', 'Romance', 'Contemporary']                                               2
# ['Books', 'Literature &amp; Fiction', 'Contemporary']                              2
# []                                                                                 2
# ['Books', 'Literature & Fiction', 'Humor & Satire']                                2
# ['Books', 'Health, Fitness &amp; Dieting', 'Mental Health']                        2
# ['Books', 'Parenting & Relationships', 'Family Relationships']                     1
# ['Books', 'Reference', 'Writing, Research &amp; Publishing Guides']                1
# ['Books', 'Business & Money', 'Job Hunting & Careers']                             1
# ['Books', 'Self-Help', 'Death & Grief']                                            1
# ['Books', 'Business &amp; Money', 'Business Culture']                              1
# ['Books', 'Literature &amp; Fiction', "Women's Fiction"]                           1
# ['Books', 'History', 'Americas']                                                   1
# ['Books', "Children's Books", 'Holidays &amp; Celebrations']                       1
# ['Books', 'History', 'World']                                                      1
# ['Books', 'Romance', 'Paranormal']                                                 1
# ['Books', 'Health, Fitness & Dieting', 'Psychology & Counseling']                  1
# ['Books', 'Humor &amp; Entertainment', 'Humor']                                    1
# ['Books', 'Literature &amp; Fiction', 'United States']                             1
# ['Books', 'Literature &amp; Fiction', 'Action &amp; Adventure']                    1
# ['Books', 'Literature &amp; Fiction']                                              1
# ['Books', 'Parenting &amp; Relationships', 'Family Relationships']                 1
# ['Books', 'Literature &amp; Fiction', 'Erotica']                                   1
# ['Books', 'Literature &amp; Fiction', 'Poetry']                                    1
# ['Books', 'Biographies & Memoirs', 'Arts & Literature']                            1
# ['Books', "Children's Books", 'Growing Up &amp; Facts of Life']                    1
# ['Books', 'Biographies &amp; Memoirs', 'Professionals &amp; Academics']            1
# ['Books', 'Self-Help', 'Relationships']                                            1
# ['Books', 'Biographies & Memoirs', 'Professionals & Academics']                    1
# ['Books', 'Health, Fitness &amp; Dieting', 'Diseases &amp; Physical Ailments']     1
# ['Books', 'Literature &amp; Fiction', 'Humor &amp; Satire']                        1
# ['Books', 'Literature &amp; Fiction', 'Short Stories &amp; Anthologies']           1
# ['Books', 'Politics & Social Sciences', 'Social Sciences']                         1
# Name: category, dtype: int64

# %%
df300 = books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '300'").sort('overall', ascending=False).limit(100).toPandas()

# %%
df300['category'].astype('str').value_counts()
# Out:
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Thrillers &amp; Suspense']    20
# ['Books', 'Literature &amp; Fiction', 'Genre Fiction']                       13
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Mystery']                      8
# ['Books', 'Biographies &amp; Memoirs', 'Arts &amp; Literature']               5
# ['Books', 'Mystery, Thriller & Suspense', 'Thrillers & Suspense']             4
# ['Books', 'Literature & Fiction', 'Genre Fiction']                            3
# ['Books', 'Literature &amp; Fiction', 'Action &amp; Adventure']               3
# ['Books', 'Literature &amp; Fiction', 'United States']                        3
# ['Books', 'Humor &amp; Entertainment', 'Humor']                               3
# ['Books', 'Biographies &amp; Memoirs', 'Specific Groups']                     2
# ['Books', 'Literature & Fiction', 'Contemporary']                             2
# ['Books', 'Reference', 'Writing, Research &amp; Publishing Guides']           2
# ['Books', 'Biographies &amp; Memoirs', 'Historical']                          2
# ['Books', 'Biographies & Memoirs', 'Memoirs']                                 2
# ['Books', 'Literature & Fiction', 'United States']                            1
# ['Books', 'Health, Fitness &amp; Dieting', 'Diets &amp; Weight Loss']         1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Regional &amp; International']       1
# ['Books', 'Literature & Fiction', 'Humor & Satire']                           1
# ['Books', 'Science Fiction &amp; Fantasy', 'Fantasy']                         1
# ['Books', 'Biographies &amp; Memoirs', 'True Crime']                          1
# ['Books', 'Arts &amp; Photography', 'Graphic Design']                         1
# ['Books', "Children's Books", 'Geography & Cultures']                         1
# ['Books', 'Arts &amp; Photography', 'History &amp; Criticism']                1
# ['Books', 'Sports & Outdoors', 'Racket Sports']                               1
# ['Books', 'Teen &amp; Young Adult', 'Literature &amp; Fiction']               1
# ['Books', 'Literature &amp; Fiction', 'Contemporary']                         1
# ['Books', 'Comics &amp; Graphic Novels', 'Graphic Novels']                    1
# ['Books', 'Biographies &amp; Memoirs', 'Memoirs']                             1
# ['Books', 'Christian Books &amp; Bibles', 'Christian Living']                 1
# ['Books', 'Biographies &amp; Memoirs', 'Professionals &amp; Academics']       1
# ['Books', 'Literature &amp; Fiction', 'Literary']                             1
# ['Books', 'Literature &amp; Fiction', 'Dramas &amp; Plays']                   1
# ['Books', 'History', 'World']                                                 1
# ['Books', 'History', 'Americas']                                              1
# ['Books', 'History', 'Ancient Civilizations']                                 1
# ['Books', 'Business &amp; Money', 'Skills']                                   1
# ['Books', 'Literature &amp; Fiction', 'Humor &amp; Satire']                   1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Beverages &amp; Wine']               1
# ['Books', 'Crafts, Hobbies &amp; Home', 'Pets &amp; Animal Care']             1
# ['Books', 'Literature & Fiction', 'Dramas & Plays']                           1
# ['Books', 'Literature & Fiction', 'Action & Adventure']                       1
# ['Books', 'Business &amp; Money', 'Economics']                                1
# Name: category, dtype: int64

# %%
df149 = books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '149'").sort('overall', ascending=False).limit(100).toPandas()

# %%
df149['category'].astype('str').value_counts()
# Out:
# ['Books', 'Politics &amp; Social Sciences', 'Politics &amp; Government']           9
# ['Books', "Children's Books", 'Growing Up &amp; Facts of Life']                    5
# ['Books', 'Business &amp; Money', 'Business Culture']                              5
# ['Books', 'Business &amp; Money', 'Economics']                                     3
# ['Books', 'Biographies &amp; Memoirs', 'Historical']                               3
# ['Books', 'Education &amp; Teaching', 'Schools &amp; Teaching']                    3
# ['Books', 'Business &amp; Money', 'Investing']                                     3
# ['Books', 'Business &amp; Money', 'Management &amp; Leadership']                   2
# ['Books', 'Business &amp; Money', 'Finance']                                       2
# ['Books', 'Self-Help', 'Relationships']                                            2
# ['Books', 'Business & Money', 'Management & Leadership']                           2
# ['Books', 'History', 'Military']                                                   2
# ['Books', 'New, Used &amp; Rental Textbooks', 'Social Sciences']                   2
# ['Books', 'Business & Money', 'Job Hunting & Careers']                             2
# ['Books', 'Politics & Social Sciences', 'Social Sciences']                         2
# ['Books', 'Health, Fitness & Dieting', 'Diseases & Physical Ailments']             2
# ['Books', 'Health, Fitness &amp; Dieting', 'Psychology &amp; Counseling']          2
# ['Books', "Children's Books", 'Literature &amp; Fiction']                          2
# ['Books', 'Business &amp; Money', 'Small Business &amp; Entrepreneurship']         1
# ['Books', 'History', 'Americas']                                                   1
# ['Books', 'Self-Help', 'Personal Transformation']                                  1
# ['Books', 'Christian Books & Bibles', 'Bible Study & Reference']                   1
# ['Books', "Children's Books", 'Action &amp; Adventure']                            1
# ['Books', 'Business &amp; Money']                                                  1
# ['Books', 'Computers & Technology', 'Networking & Cloud Computing']                1
# ['Books', 'New, Used &amp; Rental Textbooks', 'Education']                         1
# ['Books', "Children's Books", 'Arts, Music &amp; Photography']                     1
# ['Books', 'Biographies & Memoirs', 'Leaders & Notable People']                     1
# ['Books', 'Biographies &amp; Memoirs', 'Memoirs']                                  1
# ['Books', 'Politics &amp; Social Sciences', 'Social Sciences']                     1
#                                                                                   ..
# ['Books', 'New, Used &amp; Rental Textbooks', 'Medicine &amp; Health Sciences']    1
# ['Books', 'Health, Fitness &amp; Dieting', 'Exercise &amp; Fitness']               1
# ['Books', 'Business &amp; Money', 'Job Hunting &amp; Careers']                     1
# ['Books', "Children's Books", 'Science, Nature &amp; How It Works']                1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Kitchen Appliances']                      1
# ['Books', 'Medical Books', 'Medicine']                                             1
# ['Books', 'Parenting &amp; Relationships', 'Family Relationships']                 1
# ['Books', 'Politics & Social Sciences', 'Politics & Government']                   1
# ['Books', 'Arts &amp; Photography', 'Graphic Design']                              1
# ['Books', 'Test Preparation', 'Graduate School']                                   1
# ['Books', 'Science &amp; Math', 'Biological Sciences']                             1
# ['Books', 'Engineering & Transportation', 'Engineering']                           1
# ['Books', 'Business &amp; Money', 'Processes &amp; Infrastructure']                1
# ['Books', 'Literature &amp; Fiction', 'Genre Fiction']                             1
# ['Books', 'New, Used &amp; Rental Textbooks', 'Humanities']                        1
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Thrillers &amp; Suspense']          1
# ['Books', 'New, Used &amp; Rental Textbooks', 'Law']                               1
# ['Books', 'Health, Fitness &amp; Dieting']                                         1
# ['Books', 'Reference', 'Etiquette']                                                1
# ['Books', "Children's Books"]                                                      1
# ['Books', "Children's Books", 'Science, Nature & How It Works']                    1
# ['Books', 'Computers &amp; Technology', 'Hardware &amp; DIY']                      1
# ['Books', 'Computers &amp; Technology', 'Networking &amp; Cloud Computing']        1
# ['Books', 'Sports &amp; Outdoors', 'Individual Sports']                            1
# ['Books', 'Biographies & Memoirs', 'Professionals & Academics']                    1
# ['Books', 'Christian Books & Bibles', 'Theology']                                  1
# ['Books', 'Literature &amp; Fiction', "Women's Fiction"]                           1
# ['Books', 'Crafts, Hobbies &amp; Home', 'Gardening &amp; Landscape Design']        1
# ['Books', 'Arts &amp; Photography', 'Architecture']                                1
# ['Books', 'Business &amp; Money', 'International']                                 1
# Name: category, Length: 65, dtype: int64

# %%
df145 = books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '142'").sort('overall', ascending=False).limit(100).toPandas()

# %%
df145['category'].astype('str').value_counts()
# Out:
# ['Books', 'Literature &amp; Fiction', 'Genre Fiction']                       20
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Mystery']                     16
# ['Books', 'Science Fiction &amp; Fantasy', 'Science Fiction']                 7
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Thrillers &amp; Suspense']     7
# ['Books', 'Literature & Fiction', 'Genre Fiction']                            5
# ['Books', 'Christian Books & Bibles', 'Literature & Fiction']                 3
# ['Books', 'Science Fiction & Fantasy', 'Science Fiction']                     3
# ['Books', 'Mystery, Thriller & Suspense', 'Mystery']                          3
# ['Books', 'Literature &amp; Fiction', 'History &amp; Criticism']              3
# ['Books', "Children's Books", 'Literature &amp; Fiction']                     2
# ['Books', 'Literature & Fiction', 'Action & Adventure']                       2
# ['Books', 'Literature &amp; Fiction', 'Literary']                             2
# ['Books', "Children's Books", 'Growing Up &amp; Facts of Life']               2
# ['Books', 'Biographies &amp; Memoirs', 'Professionals &amp; Academics']       2
# ['Books', 'Biographies &amp; Memoirs', 'Historical']                          2
# ['Books', 'Teen &amp; Young Adult', 'Literature &amp; Fiction']               1
# ['Books', 'Christian Books & Bibles', 'Christian Living']                     1
# ['Books', 'Science Fiction &amp; Fantasy', 'Fantasy']                         1
# ['Books', 'Romance', 'Historical']                                            1
# ['Books', 'Arts & Photography', 'History & Criticism']                        1
# ['Books', "Children's Books", 'Growing Up & Facts of Life']                   1
# ['Books', 'Reference', 'Writing, Research &amp; Publishing Guides']           1
# ['Books', 'Business & Money', 'Marketing & Sales']                            1
# ['Books', 'Literature & Fiction', 'History & Criticism']                      1
# ['Books', 'History', 'Americas']                                              1
# ['Books', 'Biographies & Memoirs', 'Professionals & Academics']               1
# ['Books', 'Humor &amp; Entertainment', 'Humor']                               1
# ['Books', 'Literature &amp; Fiction', 'British &amp; Irish']                  1
# ['Books', 'New, Used & Rental Textbooks', 'Humanities']                       1
# ['Books', 'Religion &amp; Spirituality', 'Literature &amp; Fiction']          1
# ['Books', 'Teen & Young Adult', 'Literature & Fiction']                       1
# ['Books', "Children's Books", 'Science Fiction & Fantasy']                    1
# ['Books', 'Literature & Fiction', 'Short Stories & Anthologies']              1
# ['Books', 'Biographies &amp; Memoirs', 'Specific Groups']                     1
# ['Books', 'Literature &amp; Fiction', 'United States']                        1
# ['Books', 'History', 'Europe']                                                1
# Name: category, dtype: int64

# %%
df99 = books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '99'").sort('overall', ascending=False).limit(100).toPandas()

# %%
df99['category'].astype('str').value_counts()
# Out:
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Thrillers &amp; Suspense']       12
# ['Books', 'Literature &amp; Fiction', 'Genre Fiction']                           8
# ['Books', 'Mystery, Thriller & Suspense', 'Thrillers & Suspense']                6
# ['Books', 'Literature & Fiction', 'Genre Fiction']                               5
# ['Books', 'Mystery, Thriller &amp; Suspense', 'Mystery']                         4
# ['Books', "Children's Books", 'Animals']                                         3
# ['Books', 'Religion &amp; Spirituality', 'Judaism']                              3
# ['Books', "Children's Books", 'Geography &amp; Cultures']                        3
# ['Books', "Children's Books", 'Fairy Tales, Folk Tales &amp; Myths']             2
# ['Books', 'Politics & Social Sciences', 'Politics & Government']                 2
# ['Books', 'Crafts, Hobbies &amp; Home', 'Pets &amp; Animal Care']                2
# ['Books', 'History', 'World']                                                    2
# ['Books', 'Religion & Spirituality', 'Judaism']                                  2
# ['Books', 'Literature & Fiction', 'Action & Adventure']                          2
# ['Books', 'Arts &amp; Photography', 'Music']                                     2
# ['Books', 'Literature &amp; Fiction', 'History &amp; Criticism']                 2
# ['Books', 'Christian Books &amp; Bibles', 'Bible Study &amp; Reference']         2
# ['Books', 'Humor &amp; Entertainment', 'Humor']                                  2
# ['Books', 'Science Fiction &amp; Fantasy', 'Science Fiction']                    2
# ['Books', 'History', 'Americas']                                                 1
# ['Books', 'New, Used & Rental Textbooks', 'Humanities']                          1
# ['Books', 'Literature & Fiction', 'Contemporary']                                1
# ['Books', 'Literature &amp; Fiction', 'Literary']                                1
# ['Books', 'Cookbooks, Food & Wine', 'Regional & International']                  1
# ['Books', 'Crafts, Hobbies & Home', 'Pets & Animal Care']                        1
# ['Books', "Children's Books", 'Action &amp; Adventure']                          1
# ['Books', 'Science Fiction &amp; Fantasy', 'Fantasy']                            1
# ['Books', 'Christian Books & Bibles', 'Literature & Fiction']                    1
# ['Books', "Children's Books", 'Growing Up & Facts of Life']                      1
# ['Books', "Children's Books", 'Science Fiction & Fantasy']                       1
# ['Books', 'Self-Help', 'Relationships']                                          1
# ['Books', 'Literature & Fiction', 'Poetry']                                      1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Cooking Education &amp; Reference']     1
# ['Books', "Children's Books", 'Growing Up &amp; Facts of Life']                  1
# ['Books', 'Politics &amp; Social Sciences', 'Politics &amp; Government']         1
# ['Books', "Children's Books", 'Literature &amp; Fiction']                        1
# ['Books', 'New, Used &amp; Rental Textbooks', 'Humanities']                      1
# ['Books', 'Education & Teaching', 'Schools & Teaching']                          1
# ['Books', "Children's Books", 'Science Fiction &amp; Fantasy']                   1
# ['Books', 'Medical Books', 'Medicine']                                           1
# ['Books', 'Christian Books & Bibles', 'Bible Study & Reference']                 1
# ['Books', 'Humor & Entertainment', 'Humor']                                      1
# ['Books', 'Literature &amp; Fiction', 'Contemporary']                            1
# ['Books', "Children's Books", 'Activities, Crafts &amp; Games']                  1
# ['Books', 'Mystery, Thriller & Suspense', 'Mystery']                             1
# ['Books', 'Literature & Fiction', 'History & Criticism']                         1
# ['Books', 'Cookbooks, Food &amp; Wine', 'Special Diet']                          1
# ['Books', 'Literature &amp; Fiction', 'Poetry']                                  1
# ['Books', 'Literature &amp; Fiction', 'Humor &amp; Satire']                      1
# ['Books', 'Literature &amp; Fiction', 'Action &amp; Adventure']                  1
# ['Books', 'Biographies &amp; Memoirs', 'Historical']                             1
# ['Books', 'Medical Books', 'Psychology']                                         1
# ['Books', 'Biographies & Memoirs', 'Historical']                                 1
# Name: category, dtype: int64

# %%
books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '148'").sort('overall', ascending=False).limit(10).toPandas()
# Out:
#          asin     reviewerID  overall  reviewerIDIndex  \
# 0  193563920X  A8710RWTFG3IY      5.0            148.0
# 1  B00CPCYPQQ  A8710RWTFG3IY      5.0            148.0
# 2  1250040698  A8710RWTFG3IY      5.0            148.0
# 3  1400069939  A8710RWTFG3IY      5.0            148.0
# 4  1250006538  A8710RWTFG3IY      5.0            148.0
# 5  0812981693  A8710RWTFG3IY      5.0            148.0
# 6  0763644765  A8710RWTFG3IY      5.0            148.0
# 7  B0081GLCAM  A8710RWTFG3IY      5.0            148.0
# 8  1619272040  A8710RWTFG3IY      5.0            148.0
# 9  0399158774  A8710RWTFG3IY      5.0            148.0
#
#                                             category   price  \
# 0       [Books, Literature & Fiction, United States]   $9.05
# 1  [Books, Politics & Social Sciences, Politics &...
# 2     [Books, Biographies &amp; Memoirs, Historical]  $17.82
# 3    [Books, Arts &amp; Photography, Graphic Design]  $16.79
# 4  [Books, Biographies &amp; Memoirs, Leaders &am...  $11.95
# 5  [Books, Biographies &amp; Memoirs, Specific Gr...  $13.08
# 6  [Books, Children's Books, Growing Up &amp; Fac...   $6.99
# 7       [Books, Literature & Fiction, Genre Fiction]
# 8                                                 []  $25.95
# 9        [Books, Biographies &amp; Memoirs, Memoirs]   $9.90
#
#                                                title  \
# 0                   Glaciers (A Tin House New Voice)
# 1  India Dishonoured: Behind a nation&#39;s war o...
# 2  The Woman Before Wallis: Prince Edward, the Pa...
# 3  The Coat Route: Craft, Luxury, &amp; Obsession...
# 4  Defiant: The POWs Who Endured Vietnam's Most I...
# 5                       Mother Daughter Me: A Memoir
# 6              Potty (Leslie Patricelli board books)
# 7               Warm Moonlight (Kindle Single) eBook
# 8                         Desperado's Wife: A Memoir
# 9  Jujitsu Rabbi and the Godless Blonde: A True S...
#
#                                          description
# 0  [<div>"<B><I>Glaciers</I> has all the things I...
# 1                                                 []
# 2  [, Riveting[Rose] delivers a vivid account of ...
# 3  [A spirited tour of fashion history . . . <i>T...
# 4  [, You told it exactly like it was. In this un...
# 5  [The most raw, honest and engaging memoir Ive ...
# 6  [PreSBoth books feature the same smiling, bald...
# 7                                                 []
# 8  [Smart, accomplished, attractive reporter goes...
# 9  [<a href="http://www.amazon.com/gp/feature.htm...

# %%
books_index_interpret.join(Meta_Books_df_interpret, on='asin').filter("reviewerIDIndex == '463'").sort('overall', ascending=False).limit(10).toPandas()
# Out:
#          asin     reviewerID  overall  reviewerIDIndex  \
# 0  193332063X  A2RPZTZP8W80W      5.0            463.0
# 1  1484980662  A2RPZTZP8W80W      5.0            463.0
# 2  1612177379  A2RPZTZP8W80W      5.0            463.0
# 3  0547729960  A2RPZTZP8W80W      5.0            463.0
# 4  0312872380  A2RPZTZP8W80W      5.0            463.0
# 5  0385528213  A2RPZTZP8W80W      5.0            463.0
# 6  1475138733  A2RPZTZP8W80W      5.0            463.0
# 7  1622660315  A2RPZTZP8W80W      5.0            463.0
# 8  0786915897  A2RPZTZP8W80W      5.0            463.0
# 9  0985148373  A2RPZTZP8W80W      5.0            463.0
#
#                                             category   price  \
# 0                       [Books, Romance, Paranormal]  $14.95
# 1                       [Books, Romance, Paranormal]   $8.99
# 2                       [Books, Romance, Paranormal]  $15.99
# 3  [Books, Teen &amp; Young Adult, Literature &am...  $11.24
# 4    [Books, Science Fiction &amp; Fantasy, Fantasy]
# 5   [Books, Literature &amp; Fiction, Genre Fiction]
# 6                  [Books, Romance, Science Fiction]
# 7          [Books, Humor &amp; Entertainment, Humor]  $14.99
# 8  [Books, Christian Books &amp; Bibles, Literatu...   $6.95
# 9                  [Books, Romance, Science Fiction]  $11.99
#
#                                                title  \
# 0  The Witch's Dream (The Order of the Black Swan...
# 1                Wickedest Witch: Paranormal Romance
# 2                                   Apocalyptic Moon
# 3                               The Suburban Strange
# 4                  Kushiel's Dart (Kushiel's Legacy)
# 5                                        The Rapture
# 6       F814: Cyborgs: More Than Machines (Volume 2)
# 7      Cinderella Screwed Me Over (Entangled Select)
# 8  Dragons of Spring Dawning (Dragonlance Chronic...
# 9  Colonization: Book one of Paradise Reclaimed (...
#
#                                          description
# 0  [<div><i><b>Suggested Reading Order</b></i></d...
# 1  [Five Hearts "There wasn't anything that I did...
# 2  [<span>Eva Gordon writes genre bending paranor...
# 3  [Gr 9-11-Celia Balaustine, a new sophomore at ...
# 4  [HThis brilliant and daring debut, set in a sk...
# 5  [Starred Review. Apocalyptic global climate ch...
# 6  [<b>Do you love sci-fi romance? Then check out...
# 7  [, , <b>Cindi Madsen</b> sits at her computer ...
# 8  [The final installment in Weis and Hickman's C...
# 9                                               [, ]

# %%
# Generate top 10 user recommendations for each book
booksRecs = model.recommendForAllItems(10)
booksRecs.show(10, truncate=False)
# Out:
# +---------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |asinIndex|recommendations                                                                                                                                                                                                  |
# +---------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |148      |[[281543, 10.860487], [169881, 10.388498], [306332, 10.139483], [317620, 10.074364], [569432, 9.984281], [568940, 9.863988], [509337, 9.762174], [259625, 9.730604], [402846, 9.700727], [511421, 9.519455]]     |
# |463      |[[240956, 14.545721], [593886, 13.560465], [458265, 13.12389], [530236, 12.64061], [495359, 12.594008], [389109, 12.525441], [540797, 12.375052], [536115, 12.239917], [549248, 12.18397], [349636, 12.086442]]  |
# |471      |[[337349, 10.514135], [364385, 10.126316], [560793, 9.831247], [246039, 9.571961], [451075, 9.550249], [399103, 9.535681], [215210, 9.522085], [583647, 9.5139675], [119415, 9.47963], [317620, 9.200784]]       |
# |496      |[[208495, 10.754841], [523376, 10.680714], [467782, 10.425066], [337349, 10.160739], [119415, 10.1232815], [542343, 9.962791], [583647, 9.915185], [593886, 9.833786], [577831, 9.775902], [296403, 9.7703705]]  |
# |833      |[[208495, 11.065507], [523376, 10.720325], [467782, 10.50301], [119415, 10.087525], [562232, 10.0577135], [583647, 10.018521], [501112, 9.91791], [594111, 9.822707], [542343, 9.766146], [356948, 9.630974]]    |
# |1088     |[[561269, 11.193639], [169024, 10.556677], [258345, 10.161312], [306332, 10.0540495], [208495, 9.991999], [230051, 9.791831], [222844, 9.780838], [442820, 9.746594], [150006, 9.649997], [515917, 9.622335]]    |
# |1238     |[[281543, 8.319022], [208495, 8.171711], [523376, 8.1061945], [562232, 7.9684606], [119415, 7.8895874], [325903, 7.7220325], [545867, 7.7039814], [262044, 7.67546], [549359, 7.6698813], [577831, 7.663688]]    |
# |1342     |[[119415, 9.7571], [139324, 9.350543], [149365, 8.983885], [454407, 8.972718], [523376, 8.946238], [293741, 8.907986], [562232, 8.847271], [222379, 8.786049], [208495, 8.638571], [317366, 8.6164665]]          |
# |1580     |[[583647, 15.419422], [337349, 14.279066], [560793, 13.823523], [280577, 13.703566], [364385, 13.489605], [252770, 13.1362], [333129, 13.114815], [451075, 12.866261], [154563, 12.698789], [443482, 12.6987505]]|
# |1591     |[[593886, 10.45051], [240956, 9.940556], [325903, 9.47571], [394584, 9.293802], [551654, 8.888067], [577831, 8.688685], [246039, 8.686518], [497938, 8.583114], [568943, 8.576712], [184114, 8.536137]]          |
# +---------+-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 10 rows

# %%
df_booksRecs_recommendation = booksRecs.withColumn("recommendations",explode("recommendations"))

# %%
udf_user_index = udf(lambda x:x[0],IntegerType())
udf_rating = udf(lambda x: x[1], FloatType())

# %%
nrecommendations_book = df_booksRecs_recommendation.withColumn('reviewerIDIndex', udf_user_index('recommendations')).withColumn('overall', udf_rating('recommendations')).drop('recommendations')
nrecommendations_book.limit(20).show()
# Out:
# +---------+---------------+---------+
# |asinIndex|reviewerIDIndex|  overall|
# +---------+---------------+---------+
# |        1|         593886| 9.984209|
# |        1|         240956| 9.229199|
# |        1|         119415|  9.16442|
# |        1|         568943| 8.809243|
# |        1|         337349| 8.635262|
# |        1|         562232| 8.606853|
# |        1|         523376| 8.601137|
# |        1|         325903| 8.496689|
# |        1|         577831| 8.486034|
# |        1|         208495| 8.474072|
# |      206|         577831|10.757442|
# |      206|         243444|10.316485|
# |      206|         580874|10.271038|
# |      206|         293768|10.243166|
# |      206|         133281| 10.03422|
# |      206|         348488| 9.946756|
# |      206|         551891|  9.94592|
# |      206|         281543|9.8957205|
# |      206|         594111| 9.828285|
# |      206|         257515| 9.716956|
# +---------+---------------+---------+

# %%
# Generate top 10 movie recommendations for a specified set of users
users = books1_index.select(als.getUserCol()).distinct().limit(3)
userSubsetRecs = model.recommendForUserSubset(users, 10)

userSubsetRecs.show(10, truncate=False)
# Out:
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |reviewerIDIndex|recommendations                                                                                                                                                                                                   |
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |414891         |[[159215, 9.758057], [185895, 9.056629], [194090, 8.618893], [131581, 8.494107], [325685, 8.25225], [233765, 8.196823], [321030, 8.182126], [358483, 8.174082], [181476, 8.171719], [319823, 8.166932]]           |
# |137720         |[[191198, 15.173658], [88825, 13.913759], [275823, 13.401945], [201462, 13.260361], [306531, 13.140616], [157547, 13.034756], [163934, 12.603062], [278931, 12.544035], [156427, 12.51778], [82478, 12.464679]]   |
# |134090         |[[129703, 16.437304], [165777, 14.883086], [360130, 14.558597], [109352, 14.547243], [125888, 14.458511], [183481, 14.116917], [245696, 13.9031925], [148241, 13.879835], [63627, 13.667446], [208366, 13.587015]]|
# +---------------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %%
# Generate top 10 user recommendations for a specified set of items
items = books1_index.select(als.getItemCol()).distinct().limit(3)
itemsSubSetRecs = model.recommendForItemSubset(items, 10)

itemsSubSetRecs.show(10, truncate=False)
# Out:
# +---------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |asinIndex|recommendations                                                                                                                                                                                                   |
# +---------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |96304    |[[299491, 15.221222], [125350, 14.114204], [539288, 13.836814], [457624, 13.719978], [498638, 13.3598175], [447053, 13.310471], [590336, 13.086271], [313127, 12.95273], [566081, 12.916631], [161884, 12.913895]]|
# |69457    |[[442820, 17.746065], [173868, 16.044271], [432846, 15.91729], [89282, 15.792759], [512904, 15.600206], [306502, 14.932819], [429315, 14.885147], [518402, 14.846849], [345345, 14.834769], [438554, 14.772887]]  |
# |239225   |[[524114, 13.851438], [421866, 13.6727915], [299491, 12.818785], [336806, 12.75132], [411474, 12.640048], [381977, 12.621222], [465210, 12.440265], [388415, 12.360101], [268093, 11.71716], [379358, 11.646735]] |
# +---------+------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+

# %% [markdown]
# # user based cf

# %%
books_cf = books2_index.toPandas()

# %%
from pyspark.sql.functions import countDistinct
books.select(countDistinct("reviewerID"))
# Out:
# +--------------------------+
# |count(DISTINCT reviewerID)|
# +--------------------------+
# |                    603668|
# +--------------------------+

# %%
books.select(countDistinct("asin"))
# Out:
# +--------------------+
# |count(DISTINCT asin)|
# +--------------------+
# |              367982|
# +--------------------+

# %%
n_users = 603668
n_items = 367982

# %%
data_matrix = np.zeros((n_users, n_items))
for line in ratings.itertuples():
    data_matrix[line[1]-1, line[2]-1] = line[3]
